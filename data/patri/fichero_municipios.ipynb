# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
# Installing collected packages: unidecode
# Successfully installed unidecode-1.1.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import unidecode

# %% [markdown]
# #### Carga de fichero

# %%
df = pd.read_csv("C:\\Users\\pmari\\saturdaysai\\proyecto\\Exodus_urbano\\data\\Guille\\MasterSheet.csv")

# %%
df
# Out:
#        Postal code           Cities     Province Autonomous Community
# 0             1001  Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 1             1002  Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 2             1003  Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 3             1004  Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 4             1005  Vitoria-Gasteiz  Áraba/Álava           País Vasco
# ...            ...              ...          ...                  ...
# 11131        48000            Bilbo      Bizkaia           País Vasco
# 11132        49000              NaN       Zamora      Castilla y León
# 11133        50000              NaN     Zaragoza               Aragón
# 11134        51000              NaN        Ceuta                Ceuta
# 11135        52000              NaN      Melilla              Melilla
#
# [11136 rows x 4 columns]

# %%
def doClean(text):   
    
    # Quitar las expresiones entre llaves que denotan las partes de la canción
    a = re.sub('\[.*\]', '', text)
    # Quitar las aclaraciones entre paréntesis
    a = re.sub('\(.*\)', '', a)
    # Quitar acentos 
    a = unidecode.unidecode(a)
    # Quitar aquello que no sean palabras o cosa que se le parezca
    a = re.sub('\W', ' ', a) 
    # Quitar espacios extra en caso de haber
    a = re.sub('\s+', ' ', a)
    # Pasar el texto a minúsulas
    a = a.lower() 
    a = re.sub(' ', '_', a)
    #a = a.strip() 
    
    return a

# %%
df.dtypes
# Out:
# Postal code              int64
# Cities                  object
# Province                object
# Autonomous Community    object
# dtype: object

# %%
df.fillna('', inplace=True)

# %%
# df[municipios_limpios] = df[~df['Cities'].isnull()]['Cities']

# %%
df['municipio_limpio'] = df['Cities'].apply(doClean)

# %%
df.head(40)
# Out:
#     Postal code                      Cities     Province Autonomous Community  \
# 0          1001             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 1          1002             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 2          1003             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 3          1004             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 4          1005             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 5          1006             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 6          1007             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 7          1008             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 8          1009             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 9          1010             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 10         1012             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 11         1013             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 12         1015             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 13         1110             Campezo/Kanpezu  Áraba/Álava           País Vasco
# 14         1117             Campezo/Kanpezu  Áraba/Álava           País Vasco
# 15         1118                     Bernedo  Áraba/Álava           País Vasco
# 16         1120               Arraia-Maeztu  Áraba/Álava           País Vasco
# 17         1128                     Bernedo  Áraba/Álava           País Vasco
# 18         1129               Arraia-Maeztu  Áraba/Álava           País Vasco
# 19         1130                        Zuia  Áraba/Álava           País Vasco
# 20         1138                    Zigoitia  Áraba/Álava           País Vasco
# 21         1139                        Zuia  Áraba/Álava           País Vasco
# 22         1160                     Aramaio  Áraba/Álava           País Vasco
# 23         1165                     Aramaio  Áraba/Álava           País Vasco
# 24         1169                     Aramaio  Áraba/Álava           País Vasco
# 25         1170                     Legutio  Áraba/Álava           País Vasco
# 26         1171                     Legutio  Áraba/Álava           País Vasco
# 27         1191             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 28         1192             Elburgo/Burgelu  Áraba/Álava           País Vasco
# 29         1193            Alegría-Dulantzi  Áraba/Álava           País Vasco
# 30         1194                     Bernedo  Áraba/Álava           País Vasco
# 31         1195             Vitoria-Gasteiz  Áraba/Álava           País Vasco
# 32         1196                    Zigoitia  Áraba/Álava           País Vasco
# 33         1200         Agurain/Salvatierra  Áraba/Álava           País Vasco
# 34         1206                   Barrundia  Áraba/Álava           País Vasco
# 35         1207               Iruraiz-Gauna  Áraba/Álava           País Vasco
# 36         1208                   Asparrena  Áraba/Álava           País Vasco
# 37         1211                     Armiñón  Áraba/Álava           País Vasco
# 38         1212                Berantevilla  Áraba/Álava           País Vasco
# 39         1213  Erriberagoitia/Ribera Alta  Áraba/Álava           País Vasco
#
#               municipio_limpio
# 0              vitoria_gasteiz
# 1              vitoria_gasteiz
# 2              vitoria_gasteiz
# 3              vitoria_gasteiz
# 4              vitoria_gasteiz
# 5              vitoria_gasteiz
# 6              vitoria_gasteiz
# 7              vitoria_gasteiz
# 8              vitoria_gasteiz
# 9              vitoria_gasteiz
# 10             vitoria_gasteiz
# 11             vitoria_gasteiz
# 12             vitoria_gasteiz
# 13             campezo_kanpezu
# 14             campezo_kanpezu
# 15                     bernedo
# 16               arraia_maeztu
# 17                     bernedo
# 18               arraia_maeztu
# 19                        zuia
# 20                    zigoitia
# 21                        zuia
# 22                     aramaio
# 23                     aramaio
# 24                     aramaio
# 25                     legutio
# 26                     legutio
# 27             vitoria_gasteiz
# 28             elburgo_burgelu
# 29            alegria_dulantzi
# 30                     bernedo
# 31             vitoria_gasteiz
# 32                    zigoitia
# 33         agurain_salvatierra
# 34                   barrundia
# 35               iruraiz_gauna
# 36                   asparrena
# 37                     arminon
# 38                berantevilla
# 39  erriberagoitia_ribera_alta
