# %%
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import re   
import locale

# %%
trafico = pd.read_csv('recursos_trafico_carreteras_clean.csv',index_col=0)
trafico.Provincia_name[trafico['Provincia_name']=='a_coruna'] = 'coruna'
trafico[trafico['Provincia_name']=='coruna']
# Out:
#    CCAA_name Provincia_name  Total: Millones vehículos-km  \
# 52   galicia         coruna                        6661.4
#
#     porcentaje_carreteras_ccaa_y_estado
# 52                             0.805714

# %%
maestro = pd.read_csv('maestro_idiomas_ine.csv', index_col = 0, dtype={'postal_code': object})
maestro.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa   cities_es/province_es  \
# 0    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2    araba  pais_vasco  pais_vasco           amurrio/alava
# 3    araba  pais_vasco  pais_vasco           amurrio/alava
# 4    araba  pais_vasco  pais_vasco           amurrio/alava
#
#        cities_es/province            cities_es/ccaa_es  \
# 0  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2           amurrio/araba           amurrio/pais_vasco
# 3           amurrio/araba           amurrio/pais_vasco
# 4           amurrio/araba           amurrio/pais_vasco
#
#                 cities_es/ccaa      cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 1  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 2           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 3           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 4           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
#
#    province_es/ccaa  province/ccaa_es     province/ccaa
# 0  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 1  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 2  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 3  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 4  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco

# %%
union = pd.merge(maestro, trafico, left_on='province_es',right_on='Provincia_name', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15386     52001       52004           melilla           melilla     melilla
# 15387     52001       52005           melilla           melilla     melilla
# 15388     52001       52005           melilla           melilla     melilla
# 15389     52001       52006           melilla           melilla     melilla
# 15390     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa   cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2        araba  pais_vasco  pais_vasco           amurrio/alava
# 3        araba  pais_vasco  pais_vasco           amurrio/alava
# 4        araba  pais_vasco  pais_vasco           amurrio/alava
# ...        ...         ...         ...                     ...
# 15386  melilla     melilla     melilla         melilla/melilla
# 15387  melilla     melilla     melilla         melilla/melilla
# 15388  melilla     melilla     melilla         melilla/melilla
# 15389  melilla     melilla     melilla         melilla/melilla
# 15390  melilla     melilla     melilla         melilla/melilla
#
#            cities_es/province            cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2               amurrio/araba           amurrio/pais_vasco
# 3               amurrio/araba           amurrio/pais_vasco
# 4               amurrio/araba           amurrio/pais_vasco
# ...                       ...                          ...
# 15386         melilla/melilla              melilla/melilla
# 15387         melilla/melilla              melilla/melilla
# 15388         melilla/melilla              melilla/melilla
# 15389         melilla/melilla              melilla/melilla
# 15390         melilla/melilla              melilla/melilla
#
#                     cities_es/ccaa      cities/province_es  \
# 0      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 2               amurrio/pais_vasco           amurrio/alava
# 3               amurrio/pais_vasco           amurrio/alava
# 4               amurrio/pais_vasco           amurrio/alava
# ...                            ...                     ...
# 15386              melilla/melilla         melilla/melilla
# 15387              melilla/melilla         melilla/melilla
# 15388              melilla/melilla         melilla/melilla
# 15389              melilla/melilla         melilla/melilla
# 15390              melilla/melilla         melilla/melilla
#
#       province_es/ccaa_es  province_es/ccaa  province/ccaa_es  \
# 0        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 1        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 2        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 3        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 4        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# ...                   ...               ...               ...
# 15386     melilla/melilla   melilla/melilla   melilla/melilla
# 15387     melilla/melilla   melilla/melilla   melilla/melilla
# 15388     melilla/melilla   melilla/melilla   melilla/melilla
# 15389     melilla/melilla   melilla/melilla   melilla/melilla
# 15390     melilla/melilla   melilla/melilla   melilla/melilla
#
#           province/ccaa   CCAA_name Provincia_name  \
# 0      araba/pais_vasco  pais_vasco          alava
# 1      araba/pais_vasco  pais_vasco          alava
# 2      araba/pais_vasco  pais_vasco          alava
# 3      araba/pais_vasco  pais_vasco          alava
# 4      araba/pais_vasco  pais_vasco          alava
# ...                 ...         ...            ...
# 15386   melilla/melilla     melilla        melilla
# 15387   melilla/melilla     melilla        melilla
# 15388   melilla/melilla     melilla        melilla
# 15389   melilla/melilla     melilla        melilla
# 15390   melilla/melilla     melilla        melilla
#
#        Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado
# 0                            1869.3                             0.832942
# 1                            1869.3                             0.832942
# 2                            1869.3                             0.832942
# 3                            1869.3                             0.832942
# 4                            1869.3                             0.832942
# ...                             ...                                  ...
# 15386                           0.0                                  NaN
# 15387                           0.0                                  NaN
# 15388                           0.0                                  NaN
# 15389                           0.0                                  NaN
# 15390                           0.0                                  NaN
#
# [15391 rows x 21 columns]

# %%
union[union['province_es'] != union['Provincia_name']]
# Out:
#        ine_code postal_code cities_es cities province_es province ccaa_es  \
# 134        2003         NaN       NaN    NaN         NaN      NaN     NaN
# 151        2006         NaN       NaN    NaN         NaN      NaN     NaN
# 157        2008         NaN       NaN    NaN         NaN      NaN     NaN
# 165        2011         NaN       NaN    NaN         NaN      NaN     NaN
# 167        2011         NaN       NaN    NaN         NaN      NaN     NaN
# ...         ...         ...       ...    ...         ...      ...     ...
# 15235     50217         NaN       NaN    NaN         NaN      NaN     NaN
# 15259     50238         NaN       NaN    NaN         NaN      NaN     NaN
# 15274     50248         NaN       NaN    NaN         NaN      NaN     NaN
# 15332     50297         NaN       NaN    NaN         NaN      NaN     NaN
# 15342     50297         NaN       NaN    NaN         NaN      NaN     NaN
#
#       ccaa cities_es/province_es cities_es/province cities_es/ccaa_es  \
# 134    NaN                   NaN                NaN               NaN
# 151    NaN                   NaN                NaN               NaN
# 157    NaN                   NaN                NaN               NaN
# 165    NaN                   NaN                NaN               NaN
# 167    NaN                   NaN                NaN               NaN
# ...    ...                   ...                ...               ...
# 15235  NaN                   NaN                NaN               NaN
# 15259  NaN                   NaN                NaN               NaN
# 15274  NaN                   NaN                NaN               NaN
# 15332  NaN                   NaN                NaN               NaN
# 15342  NaN                   NaN                NaN               NaN
#
#       cities_es/ccaa cities/province_es province_es/ccaa_es province_es/ccaa  \
# 134              NaN                NaN                 NaN              NaN
# 151              NaN                NaN                 NaN              NaN
# 157              NaN                NaN                 NaN              NaN
# 165              NaN                NaN                 NaN              NaN
# 167              NaN                NaN                 NaN              NaN
# ...              ...                ...                 ...              ...
# 15235            NaN                NaN                 NaN              NaN
# 15259            NaN                NaN                 NaN              NaN
# 15274            NaN                NaN                 NaN              NaN
# 15332            NaN                NaN                 NaN              NaN
# 15342            NaN                NaN                 NaN              NaN
#
#       province/ccaa_es province/ccaa CCAA_name Provincia_name  \
# 134                NaN           NaN       NaN            NaN
# 151                NaN           NaN       NaN            NaN
# 157                NaN           NaN       NaN            NaN
# 165                NaN           NaN       NaN            NaN
# 167                NaN           NaN       NaN            NaN
# ...                ...           ...       ...            ...
# 15235              NaN           NaN       NaN            NaN
# 15259              NaN           NaN       NaN            NaN
# 15274              NaN           NaN       NaN            NaN
# 15332              NaN           NaN       NaN            NaN
# 15342              NaN           NaN       NaN            NaN
#
#        Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado
# 134                             NaN                                  NaN
# 151                             NaN                                  NaN
# 157                             NaN                                  NaN
# 165                             NaN                                  NaN
# 167                             NaN                                  NaN
# ...                             ...                                  ...
# 15235                           NaN                                  NaN
# 15259                           NaN                                  NaN
# 15274                           NaN                                  NaN
# 15332                           NaN                                  NaN
# 15342                           NaN                                  NaN
#
# [739 rows x 21 columns]

# %%
union[union['province_es'] != union['Provincia_name']].shape
# Out:
# (739, 21)

# %%
union.drop(['CCAA_name', 'Provincia_name'], axis=1, inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa   cities_es/province_es  \
# 0    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2    araba  pais_vasco  pais_vasco           amurrio/alava
# 3    araba  pais_vasco  pais_vasco           amurrio/alava
# 4    araba  pais_vasco  pais_vasco           amurrio/alava
#
#        cities_es/province            cities_es/ccaa_es  \
# 0  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2           amurrio/araba           amurrio/pais_vasco
# 3           amurrio/araba           amurrio/pais_vasco
# 4           amurrio/araba           amurrio/pais_vasco
#
#                 cities_es/ccaa      cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 1  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 2           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 3           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 4           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
#
#    province_es/ccaa  province/ccaa_es     province/ccaa  \
# 0  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 1  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 2  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 3  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 4  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942

# %%
empresas_autobuses = pd.read_csv('recursos_empresas_autobuses_clean.csv',index_col=0)
empresas_autobuses
# Out:
#            Municipio  bus_based_companies_count
# 0          barcelona                          5
# 1            caceres                          3
# 2              soria                          3
# 3               jaen                          3
# 4          salamanca                          3
# ..               ...                        ...
# 72           logrono                          1
# 73  monet_del_valles                          1
# 74              lugo                          1
# 75         catarroja                          1
# 76         santander                          1
#
# [77 rows x 2 columns]

# %%
union = pd.merge(union, empresas_autobuses, left_on='cities_es',right_on='Municipio', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15386     52001       52004           melilla           melilla     melilla
# 15387     52001       52005           melilla           melilla     melilla
# 15388     52001       52005           melilla           melilla     melilla
# 15389     52001       52006           melilla           melilla     melilla
# 15390     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa   cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2        araba  pais_vasco  pais_vasco           amurrio/alava
# 3        araba  pais_vasco  pais_vasco           amurrio/alava
# 4        araba  pais_vasco  pais_vasco           amurrio/alava
# ...        ...         ...         ...                     ...
# 15386  melilla     melilla     melilla         melilla/melilla
# 15387  melilla     melilla     melilla         melilla/melilla
# 15388  melilla     melilla     melilla         melilla/melilla
# 15389  melilla     melilla     melilla         melilla/melilla
# 15390  melilla     melilla     melilla         melilla/melilla
#
#            cities_es/province            cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2               amurrio/araba           amurrio/pais_vasco
# 3               amurrio/araba           amurrio/pais_vasco
# 4               amurrio/araba           amurrio/pais_vasco
# ...                       ...                          ...
# 15386         melilla/melilla              melilla/melilla
# 15387         melilla/melilla              melilla/melilla
# 15388         melilla/melilla              melilla/melilla
# 15389         melilla/melilla              melilla/melilla
# 15390         melilla/melilla              melilla/melilla
#
#                     cities_es/ccaa      cities/province_es  \
# 0      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 2               amurrio/pais_vasco           amurrio/alava
# 3               amurrio/pais_vasco           amurrio/alava
# 4               amurrio/pais_vasco           amurrio/alava
# ...                            ...                     ...
# 15386              melilla/melilla         melilla/melilla
# 15387              melilla/melilla         melilla/melilla
# 15388              melilla/melilla         melilla/melilla
# 15389              melilla/melilla         melilla/melilla
# 15390              melilla/melilla         melilla/melilla
#
#       province_es/ccaa_es  province_es/ccaa  province/ccaa_es  \
# 0        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 1        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 2        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 3        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 4        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# ...                   ...               ...               ...
# 15386     melilla/melilla   melilla/melilla   melilla/melilla
# 15387     melilla/melilla   melilla/melilla   melilla/melilla
# 15388     melilla/melilla   melilla/melilla   melilla/melilla
# 15389     melilla/melilla   melilla/melilla   melilla/melilla
# 15390     melilla/melilla   melilla/melilla   melilla/melilla
#
#           province/ccaa  Total: Millones vehículos-km  \
# 0      araba/pais_vasco                        1869.3
# 1      araba/pais_vasco                        1869.3
# 2      araba/pais_vasco                        1869.3
# 3      araba/pais_vasco                        1869.3
# 4      araba/pais_vasco                        1869.3
# ...                 ...                           ...
# 15386   melilla/melilla                           0.0
# 15387   melilla/melilla                           0.0
# 15388   melilla/melilla                           0.0
# 15389   melilla/melilla                           0.0
# 15390   melilla/melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado Municipio  \
# 0                                 0.832942       NaN
# 1                                 0.832942       NaN
# 2                                 0.832942       NaN
# 3                                 0.832942       NaN
# 4                                 0.832942       NaN
# ...                                    ...       ...
# 15386                                  NaN       NaN
# 15387                                  NaN       NaN
# 15388                                  NaN       NaN
# 15389                                  NaN       NaN
# 15390                                  NaN       NaN
#
#        bus_based_companies_count
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 15386                        NaN
# 15387                        NaN
# 15388                        NaN
# 15389                        NaN
# 15390                        NaN
#
# [15391 rows x 21 columns]

# %%
union[union['bus_based_companies_count'] > 0]
# Out:
#        ine_code postal_code cities_es    cities province_es  province  \
# 60         1036       01400    llodio    laudio       alava     araba
# 135        2003       02140  albacete  albacete    albacete  albacete
# 136        2003       02155  albacete  albacete    albacete  albacete
# 137        2003       02328  albacete  albacete    albacete  albacete
# 138        2003       02512  albacete  albacete    albacete  albacete
# ...         ...         ...       ...       ...         ...       ...
# 15358     50297       50014  zaragoza  zaragoza    zaragoza  zaragoza
# 15359     50297       50015  zaragoza  zaragoza    zaragoza  zaragoza
# 15360     50297       50016  zaragoza  zaragoza    zaragoza  zaragoza
# 15361     50297       50017  zaragoza  zaragoza    zaragoza  zaragoza
# 15362     50297       50008  zaragoza  zaragoza    zaragoza  zaragoza
#
#                   ccaa_es                ccaa cities_es/province_es  \
# 60             pais_vasco          pais_vasco          llodio/alava
# 135    castilla_la_mancha  castilla_la_mancha     albacete/albacete
# 136    castilla_la_mancha  castilla_la_mancha     albacete/albacete
# 137    castilla_la_mancha  castilla_la_mancha     albacete/albacete
# 138    castilla_la_mancha  castilla_la_mancha     albacete/albacete
# ...                   ...                 ...                   ...
# 15358              aragon              aragon     zaragoza/zaragoza
# 15359              aragon              aragon     zaragoza/zaragoza
# 15360              aragon              aragon     zaragoza/zaragoza
# 15361              aragon              aragon     zaragoza/zaragoza
# 15362              aragon              aragon     zaragoza/zaragoza
#
#       cities_es/province            cities_es/ccaa_es  \
# 60          llodio/araba            llodio/pais_vasco
# 135    albacete/albacete  albacete/castilla_la_mancha
# 136    albacete/albacete  albacete/castilla_la_mancha
# 137    albacete/albacete  albacete/castilla_la_mancha
# 138    albacete/albacete  albacete/castilla_la_mancha
# ...                  ...                          ...
# 15358  zaragoza/zaragoza              zaragoza/aragon
# 15359  zaragoza/zaragoza              zaragoza/aragon
# 15360  zaragoza/zaragoza              zaragoza/aragon
# 15361  zaragoza/zaragoza              zaragoza/aragon
# 15362  zaragoza/zaragoza              zaragoza/aragon
#
#                     cities_es/ccaa cities/province_es  \
# 60               llodio/pais_vasco       laudio/alava
# 135    albacete/castilla_la_mancha  albacete/albacete
# 136    albacete/castilla_la_mancha  albacete/albacete
# 137    albacete/castilla_la_mancha  albacete/albacete
# 138    albacete/castilla_la_mancha  albacete/albacete
# ...                            ...                ...
# 15358              zaragoza/aragon  zaragoza/zaragoza
# 15359              zaragoza/aragon  zaragoza/zaragoza
# 15360              zaragoza/aragon  zaragoza/zaragoza
# 15361              zaragoza/aragon  zaragoza/zaragoza
# 15362              zaragoza/aragon  zaragoza/zaragoza
#
#                province_es/ccaa_es             province_es/ccaa  \
# 60                alava/pais_vasco             alava/pais_vasco
# 135    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# 136    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# 137    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# 138    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# ...                            ...                          ...
# 15358              zaragoza/aragon              zaragoza/aragon
# 15359              zaragoza/aragon              zaragoza/aragon
# 15360              zaragoza/aragon              zaragoza/aragon
# 15361              zaragoza/aragon              zaragoza/aragon
# 15362              zaragoza/aragon              zaragoza/aragon
#
#                   province/ccaa_es                province/ccaa  \
# 60                araba/pais_vasco             araba/pais_vasco
# 135    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# 136    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# 137    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# 138    albacete/castilla_la_mancha  albacete/castilla_la_mancha
# ...                            ...                          ...
# 15358              zaragoza/aragon              zaragoza/aragon
# 15359              zaragoza/aragon              zaragoza/aragon
# 15360              zaragoza/aragon              zaragoza/aragon
# 15361              zaragoza/aragon              zaragoza/aragon
# 15362              zaragoza/aragon              zaragoza/aragon
#
#        Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 60                          1869.30                             0.832942
# 135                         2849.71                             0.872415
# 136                         2849.71                             0.872415
# 137                         2849.71                             0.872415
# 138                         2849.71                             0.872415
# ...                             ...                                  ...
# 15358                       4539.27                             0.983211
# 15359                       4539.27                             0.983211
# 15360                       4539.27                             0.983211
# 15361                       4539.27                             0.983211
# 15362                       4539.27                             0.983211
#
#       Municipio  bus_based_companies_count
# 60       llodio                        1.0
# 135    albacete                        1.0
# 136    albacete                        1.0
# 137    albacete                        1.0
# 138    albacete                        1.0
# ...         ...                        ...
# 15358  zaragoza                        1.0
# 15359  zaragoza                        1.0
# 15360  zaragoza                        1.0
# 15361  zaragoza                        1.0
# 15362  zaragoza                        1.0
#
# [622 rows x 21 columns]

# %%
union.drop('Municipio',axis=1,inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa   cities_es/province_es  \
# 0    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2    araba  pais_vasco  pais_vasco           amurrio/alava
# 3    araba  pais_vasco  pais_vasco           amurrio/alava
# 4    araba  pais_vasco  pais_vasco           amurrio/alava
#
#        cities_es/province            cities_es/ccaa_es  \
# 0  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2           amurrio/araba           amurrio/pais_vasco
# 3           amurrio/araba           amurrio/pais_vasco
# 4           amurrio/araba           amurrio/pais_vasco
#
#                 cities_es/ccaa      cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 1  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 2           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 3           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 4           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
#
#    province_es/ccaa  province/ccaa_es     province/ccaa  \
# 0  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 1  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 2  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 3  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 4  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942
#
#    bus_based_companies_count
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
cobertura_media = pd.read_csv('recursos_cobertura_media_clean.csv',index_col=0)
cobertura_media
# Out:
#      Provinicia              Municipio      Cod ESP  \
# 0         araba       alegria_dulantzi   1001000100
# 1         araba                amurrio   1002000100
# 2         araba                aramaio   1003000100
# 3         araba             artziniega   1004000100
# 4         araba                arminon   1006000100
# ...         ...                    ...          ...
# 8119   zaragoza                   biel  50901000100
# 8120   zaragoza               marracos  50902000100
# 8121   zaragoza  villamayor_de_gallego  50903000100
# 8122      ceuta                  ceuta  51001000100
# 8123    melilla                melilla  52001000300
#
#       Calidad_Cobertura_fija&movil_%
# 0                              65.00
# 1                              62.75
# 2                              62.22
# 3                              62.86
# 4                              66.67
# ...                              ...
# 8119                           25.00
# 8120                           45.00
# 8121                           77.50
# 8122                           72.50
# 8123                          100.00
#
# [8124 rows x 4 columns]

# %%
union = pd.merge(union, cobertura_media, left_on='cities_es',right_on='Municipio', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15468     52001       52004           melilla           melilla     melilla
# 15469     52001       52005           melilla           melilla     melilla
# 15470     52001       52005           melilla           melilla     melilla
# 15471     52001       52006           melilla           melilla     melilla
# 15472     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa   cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2        araba  pais_vasco  pais_vasco           amurrio/alava
# 3        araba  pais_vasco  pais_vasco           amurrio/alava
# 4        araba  pais_vasco  pais_vasco           amurrio/alava
# ...        ...         ...         ...                     ...
# 15468  melilla     melilla     melilla         melilla/melilla
# 15469  melilla     melilla     melilla         melilla/melilla
# 15470  melilla     melilla     melilla         melilla/melilla
# 15471  melilla     melilla     melilla         melilla/melilla
# 15472  melilla     melilla     melilla         melilla/melilla
#
#            cities_es/province            cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2               amurrio/araba           amurrio/pais_vasco
# 3               amurrio/araba           amurrio/pais_vasco
# 4               amurrio/araba           amurrio/pais_vasco
# ...                       ...                          ...
# 15468         melilla/melilla              melilla/melilla
# 15469         melilla/melilla              melilla/melilla
# 15470         melilla/melilla              melilla/melilla
# 15471         melilla/melilla              melilla/melilla
# 15472         melilla/melilla              melilla/melilla
#
#                     cities_es/ccaa      cities/province_es  \
# 0      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 2               amurrio/pais_vasco           amurrio/alava
# 3               amurrio/pais_vasco           amurrio/alava
# 4               amurrio/pais_vasco           amurrio/alava
# ...                            ...                     ...
# 15468              melilla/melilla         melilla/melilla
# 15469              melilla/melilla         melilla/melilla
# 15470              melilla/melilla         melilla/melilla
# 15471              melilla/melilla         melilla/melilla
# 15472              melilla/melilla         melilla/melilla
#
#       province_es/ccaa_es  province_es/ccaa  province/ccaa_es  \
# 0        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 1        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 2        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 3        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 4        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# ...                   ...               ...               ...
# 15468     melilla/melilla   melilla/melilla   melilla/melilla
# 15469     melilla/melilla   melilla/melilla   melilla/melilla
# 15470     melilla/melilla   melilla/melilla   melilla/melilla
# 15471     melilla/melilla   melilla/melilla   melilla/melilla
# 15472     melilla/melilla   melilla/melilla   melilla/melilla
#
#           province/ccaa  Total: Millones vehículos-km  \
# 0      araba/pais_vasco                        1869.3
# 1      araba/pais_vasco                        1869.3
# 2      araba/pais_vasco                        1869.3
# 3      araba/pais_vasco                        1869.3
# 4      araba/pais_vasco                        1869.3
# ...                 ...                           ...
# 15468   melilla/melilla                           0.0
# 15469   melilla/melilla                           0.0
# 15470   melilla/melilla                           0.0
# 15471   melilla/melilla                           0.0
# 15472   melilla/melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15468                                  NaN                        NaN
# 15469                                  NaN                        NaN
# 15470                                  NaN                        NaN
# 15471                                  NaN                        NaN
# 15472                                  NaN                        NaN
#
#       Provinicia         Municipio       Cod ESP  \
# 0          araba  alegria_dulantzi  1.001000e+09
# 1          araba  alegria_dulantzi  1.001000e+09
# 2          araba           amurrio  1.002000e+09
# 3          araba           amurrio  1.002000e+09
# 4          araba           amurrio  1.002000e+09
# ...          ...               ...           ...
# 15468    melilla           melilla  5.200100e+10
# 15469    melilla           melilla  5.200100e+10
# 15470    melilla           melilla  5.200100e+10
# 15471    melilla           melilla  5.200100e+10
# 15472    melilla           melilla  5.200100e+10
#
#        Calidad_Cobertura_fija&movil_%
# 0                               65.00
# 1                               65.00
# 2                               62.75
# 3                               62.75
# 4                               62.75
# ...                               ...
# 15468                          100.00
# 15469                          100.00
# 15470                          100.00
# 15471                          100.00
# 15472                          100.00
#
# [15473 rows x 24 columns]

# %%
union[union['Calidad_Cobertura_fija&movil_%'] > 0]
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15468     52001       52004           melilla           melilla     melilla
# 15469     52001       52005           melilla           melilla     melilla
# 15470     52001       52005           melilla           melilla     melilla
# 15471     52001       52006           melilla           melilla     melilla
# 15472     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa   cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2        araba  pais_vasco  pais_vasco           amurrio/alava
# 3        araba  pais_vasco  pais_vasco           amurrio/alava
# 4        araba  pais_vasco  pais_vasco           amurrio/alava
# ...        ...         ...         ...                     ...
# 15468  melilla     melilla     melilla         melilla/melilla
# 15469  melilla     melilla     melilla         melilla/melilla
# 15470  melilla     melilla     melilla         melilla/melilla
# 15471  melilla     melilla     melilla         melilla/melilla
# 15472  melilla     melilla     melilla         melilla/melilla
#
#            cities_es/province            cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2               amurrio/araba           amurrio/pais_vasco
# 3               amurrio/araba           amurrio/pais_vasco
# 4               amurrio/araba           amurrio/pais_vasco
# ...                       ...                          ...
# 15468         melilla/melilla              melilla/melilla
# 15469         melilla/melilla              melilla/melilla
# 15470         melilla/melilla              melilla/melilla
# 15471         melilla/melilla              melilla/melilla
# 15472         melilla/melilla              melilla/melilla
#
#                     cities_es/ccaa      cities/province_es  \
# 0      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 2               amurrio/pais_vasco           amurrio/alava
# 3               amurrio/pais_vasco           amurrio/alava
# 4               amurrio/pais_vasco           amurrio/alava
# ...                            ...                     ...
# 15468              melilla/melilla         melilla/melilla
# 15469              melilla/melilla         melilla/melilla
# 15470              melilla/melilla         melilla/melilla
# 15471              melilla/melilla         melilla/melilla
# 15472              melilla/melilla         melilla/melilla
#
#       province_es/ccaa_es  province_es/ccaa  province/ccaa_es  \
# 0        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 1        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 2        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 3        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 4        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# ...                   ...               ...               ...
# 15468     melilla/melilla   melilla/melilla   melilla/melilla
# 15469     melilla/melilla   melilla/melilla   melilla/melilla
# 15470     melilla/melilla   melilla/melilla   melilla/melilla
# 15471     melilla/melilla   melilla/melilla   melilla/melilla
# 15472     melilla/melilla   melilla/melilla   melilla/melilla
#
#           province/ccaa  Total: Millones vehículos-km  \
# 0      araba/pais_vasco                        1869.3
# 1      araba/pais_vasco                        1869.3
# 2      araba/pais_vasco                        1869.3
# 3      araba/pais_vasco                        1869.3
# 4      araba/pais_vasco                        1869.3
# ...                 ...                           ...
# 15468   melilla/melilla                           0.0
# 15469   melilla/melilla                           0.0
# 15470   melilla/melilla                           0.0
# 15471   melilla/melilla                           0.0
# 15472   melilla/melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15468                                  NaN                        NaN
# 15469                                  NaN                        NaN
# 15470                                  NaN                        NaN
# 15471                                  NaN                        NaN
# 15472                                  NaN                        NaN
#
#       Provinicia         Municipio       Cod ESP  \
# 0          araba  alegria_dulantzi  1.001000e+09
# 1          araba  alegria_dulantzi  1.001000e+09
# 2          araba           amurrio  1.002000e+09
# 3          araba           amurrio  1.002000e+09
# 4          araba           amurrio  1.002000e+09
# ...          ...               ...           ...
# 15468    melilla           melilla  5.200100e+10
# 15469    melilla           melilla  5.200100e+10
# 15470    melilla           melilla  5.200100e+10
# 15471    melilla           melilla  5.200100e+10
# 15472    melilla           melilla  5.200100e+10
#
#        Calidad_Cobertura_fija&movil_%
# 0                               65.00
# 1                               65.00
# 2                               62.75
# 3                               62.75
# 4                               62.75
# ...                               ...
# 15468                          100.00
# 15469                          100.00
# 15470                          100.00
# 15471                          100.00
# 15472                          100.00
#
# [13725 rows x 24 columns]

# %%
union.shape
# Out:
# (15473, 24)

# %% [markdown]
# La gran mayoría de municipios coinciden. ON AND ON

# %%
union.drop(['Municipio','Cod ESP','Provinicia'],axis=1,inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa   cities_es/province_es  \
# 0    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2    araba  pais_vasco  pais_vasco           amurrio/alava
# 3    araba  pais_vasco  pais_vasco           amurrio/alava
# 4    araba  pais_vasco  pais_vasco           amurrio/alava
#
#        cities_es/province            cities_es/ccaa_es  \
# 0  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2           amurrio/araba           amurrio/pais_vasco
# 3           amurrio/araba           amurrio/pais_vasco
# 4           amurrio/araba           amurrio/pais_vasco
#
#                 cities_es/ccaa      cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 1  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 2           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 3           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 4           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
#
#    province_es/ccaa  province/ccaa_es     province/ccaa  \
# 0  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 1  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 2  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 3  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 4  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942
#
#    bus_based_companies_count  Calidad_Cobertura_fija&movil_%
# 0                        NaN                           65.00
# 1                        NaN                           65.00
# 2                        NaN                           62.75
# 3                        NaN                           62.75
# 4                        NaN                           62.75

# %%
accesibilidad_media_provincial = pd.read_csv('recursos_accesibilidad_ciudades_ccaa.csv',index_col=0)
accesibilidad_media_provincial
# Out:
#     GID_0 NAME_0     GID_1                      NAME_1  accessibility_mean
# 853   ESP  Spain   ESP.1_1                   andalucia           51.600938
# 854   ESP  Spain   ESP.2_1                      aragon           62.648308
# 855   ESP  Spain   ESP.3_1                   cantabria           30.750593
# 856   ESP  Spain   ESP.4_1          castilla_la_mancha           58.622329
# 857   ESP  Spain   ESP.5_1             castilla_y_leon           52.068456
# 858   ESP  Spain   ESP.6_1                    cataluna           37.202517
# 859   ESP  Spain   ESP.7_1             ceuta_y_melilla            5.638889
# 860   ESP  Spain   ESP.8_1         comunidad_de_madrid           17.292365
# 861   ESP  Spain   ESP.9_1  comunidad_foral_de_navarra           30.136247
# 862   ESP  Spain  ESP.10_1        comunidad_valenciana           32.981396
# 863   ESP  Spain  ESP.11_1                 extremadura           63.744231
# 864   ESP  Spain  ESP.12_1                     galicia           42.585970
# 865   ESP  Spain  ESP.13_1              islas_baleares           47.560710
# 866   ESP  Spain  ESP.14_1              islas_canarias           86.588445
# 867   ESP  Spain  ESP.15_1                    la_rioja           36.967848
# 868   ESP  Spain  ESP.16_1                  pais_vasco           18.406372
# 869   ESP  Spain  ESP.17_1      principado_de_asturias           43.839053
# 870   ESP  Spain  ESP.18_1            region_de_murcia           35.040477

# %%
accesibilidad_media_provincial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 853 to 870
# Data columns (total 5 columns):
# GID_0                 18 non-null object
# NAME_0                18 non-null object
# GID_1                 18 non-null object
# NAME_1                18 non-null object
# accessibility_mean    18 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 864.0+ bytes

# %% [markdown]
# Time it takes to travel to the nearest urban center in 2015. Units are minutes, hours, days, and months via surface transit.
# An urban center is defined as a contiguous area with 1,500 or more inhabitants per km² or a majority of built-up land cover coincident with a population center of at least 50,000 inhabitants.

# %%
union = pd.merge(union, accesibilidad_media_provincial, left_on='ccaa_es',right_on='NAME_1', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15468     52001       52004           melilla           melilla     melilla
# 15469     52001       52005           melilla           melilla     melilla
# 15470     52001       52005           melilla           melilla     melilla
# 15471     52001       52006           melilla           melilla     melilla
# 15472     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa   cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2        araba  pais_vasco  pais_vasco           amurrio/alava
# 3        araba  pais_vasco  pais_vasco           amurrio/alava
# 4        araba  pais_vasco  pais_vasco           amurrio/alava
# ...        ...         ...         ...                     ...
# 15468  melilla     melilla     melilla         melilla/melilla
# 15469  melilla     melilla     melilla         melilla/melilla
# 15470  melilla     melilla     melilla         melilla/melilla
# 15471  melilla     melilla     melilla         melilla/melilla
# 15472  melilla     melilla     melilla         melilla/melilla
#
#            cities_es/province            cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2               amurrio/araba           amurrio/pais_vasco
# 3               amurrio/araba           amurrio/pais_vasco
# 4               amurrio/araba           amurrio/pais_vasco
# ...                       ...                          ...
# 15468         melilla/melilla              melilla/melilla
# 15469         melilla/melilla              melilla/melilla
# 15470         melilla/melilla              melilla/melilla
# 15471         melilla/melilla              melilla/melilla
# 15472         melilla/melilla              melilla/melilla
#
#                     cities_es/ccaa      cities/province_es  \
# 0      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 2               amurrio/pais_vasco           amurrio/alava
# 3               amurrio/pais_vasco           amurrio/alava
# 4               amurrio/pais_vasco           amurrio/alava
# ...                            ...                     ...
# 15468              melilla/melilla         melilla/melilla
# 15469              melilla/melilla         melilla/melilla
# 15470              melilla/melilla         melilla/melilla
# 15471              melilla/melilla         melilla/melilla
# 15472              melilla/melilla         melilla/melilla
#
#       province_es/ccaa_es  province_es/ccaa  province/ccaa_es  \
# 0        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 1        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 2        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 3        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 4        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# ...                   ...               ...               ...
# 15468     melilla/melilla   melilla/melilla   melilla/melilla
# 15469     melilla/melilla   melilla/melilla   melilla/melilla
# 15470     melilla/melilla   melilla/melilla   melilla/melilla
# 15471     melilla/melilla   melilla/melilla   melilla/melilla
# 15472     melilla/melilla   melilla/melilla   melilla/melilla
#
#           province/ccaa  Total: Millones vehículos-km  \
# 0      araba/pais_vasco                        1869.3
# 1      araba/pais_vasco                        1869.3
# 2      araba/pais_vasco                        1869.3
# 3      araba/pais_vasco                        1869.3
# 4      araba/pais_vasco                        1869.3
# ...                 ...                           ...
# 15468   melilla/melilla                           0.0
# 15469   melilla/melilla                           0.0
# 15470   melilla/melilla                           0.0
# 15471   melilla/melilla                           0.0
# 15472   melilla/melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15468                                  NaN                        NaN
# 15469                                  NaN                        NaN
# 15470                                  NaN                        NaN
# 15471                                  NaN                        NaN
# 15472                                  NaN                        NaN
#
#        Calidad_Cobertura_fija&movil_% GID_0 NAME_0     GID_1      NAME_1  \
# 0                               65.00   ESP  Spain  ESP.16_1  pais_vasco
# 1                               65.00   ESP  Spain  ESP.16_1  pais_vasco
# 2                               62.75   ESP  Spain  ESP.16_1  pais_vasco
# 3                               62.75   ESP  Spain  ESP.16_1  pais_vasco
# 4                               62.75   ESP  Spain  ESP.16_1  pais_vasco
# ...                               ...   ...    ...       ...         ...
# 15468                          100.00   NaN    NaN       NaN         NaN
# 15469                          100.00   NaN    NaN       NaN         NaN
# 15470                          100.00   NaN    NaN       NaN         NaN
# 15471                          100.00   NaN    NaN       NaN         NaN
# 15472                          100.00   NaN    NaN       NaN         NaN
#
#        accessibility_mean
# 0               18.406372
# 1               18.406372
# 2               18.406372
# 3               18.406372
# 4               18.406372
# ...                   ...
# 15468                 NaN
# 15469                 NaN
# 15470                 NaN
# 15471                 NaN
# 15472                 NaN
#
# [15473 rows x 26 columns]

# %%
union.drop(['GID_0','NAME_0','GID_1','NAME_1'],axis=1,inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa   cities_es/province_es  \
# 0    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1    araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2    araba  pais_vasco  pais_vasco           amurrio/alava
# 3    araba  pais_vasco  pais_vasco           amurrio/alava
# 4    araba  pais_vasco  pais_vasco           amurrio/alava
#
#        cities_es/province            cities_es/ccaa_es  \
# 0  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1  alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2           amurrio/araba           amurrio/pais_vasco
# 3           amurrio/araba           amurrio/pais_vasco
# 4           amurrio/araba           amurrio/pais_vasco
#
#                 cities_es/ccaa      cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 1  alegria_dulantzi/pais_vasco  alegria_dulantzi/alava    alava/pais_vasco
# 2           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 3           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
# 4           amurrio/pais_vasco           amurrio/alava    alava/pais_vasco
#
#    province_es/ccaa  province/ccaa_es     province/ccaa  \
# 0  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 1  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 2  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 3  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 4  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942
#
#    bus_based_companies_count  Calidad_Cobertura_fija&movil_%  \
# 0                        NaN                           65.00
# 1                        NaN                           65.00
# 2                        NaN                           62.75
# 3                        NaN                           62.75
# 4                        NaN                           62.75
#
#    accessibility_mean
# 0           18.406372
# 1           18.406372
# 2           18.406372
# 3           18.406372
# 4           18.406372

# %%
union[union['accessibility_mean']>0]
# Out:
#        ine_code postal_code              cities_es                 cities  \
# 0          1001       01240       alegria_dulantzi       alegria_dulantzi
# 1          1001       01193       alegria_dulantzi       alegria_dulantzi
# 2          1002       01450                amurrio                amurrio
# 3          1002       01468                amurrio                amurrio
# 4          1002       01470                amurrio                amurrio
# ...         ...         ...                    ...                    ...
# 15446     50298       50830                 alagon                 alagon
# 15447     50298       50810                  zuera                  zuera
# 15448     50901       50619                   asin                   asin
# 15449     50902       50616           piedratajada           piedratajada
# 15450     50903       50162  villamayor_de_gallego  villamayor_de_gallego
#
#       province_es  province     ccaa_es        ccaa  \
# 0           alava     araba  pais_vasco  pais_vasco
# 1           alava     araba  pais_vasco  pais_vasco
# 2           alava     araba  pais_vasco  pais_vasco
# 3           alava     araba  pais_vasco  pais_vasco
# 4           alava     araba  pais_vasco  pais_vasco
# ...           ...       ...         ...         ...
# 15446    zaragoza  zaragoza      aragon      aragon
# 15447    zaragoza  zaragoza      aragon      aragon
# 15448    zaragoza  zaragoza      aragon      aragon
# 15449    zaragoza  zaragoza      aragon      aragon
# 15450    zaragoza  zaragoza      aragon      aragon
#
#                 cities_es/province_es              cities_es/province  \
# 0              alegria_dulantzi/alava          alegria_dulantzi/araba
# 1              alegria_dulantzi/alava          alegria_dulantzi/araba
# 2                       amurrio/alava                   amurrio/araba
# 3                       amurrio/alava                   amurrio/araba
# 4                       amurrio/alava                   amurrio/araba
# ...                               ...                             ...
# 15446                 alagon/zaragoza                 alagon/zaragoza
# 15447                  zuera/zaragoza                  zuera/zaragoza
# 15448                   asin/zaragoza                   asin/zaragoza
# 15449           piedratajada/zaragoza           piedratajada/zaragoza
# 15450  villamayor_de_gallego/zaragoza  villamayor_de_gallego/zaragoza
#
#                   cities_es/ccaa_es                cities_es/ccaa  \
# 0       alegria_dulantzi/pais_vasco   alegria_dulantzi/pais_vasco
# 1       alegria_dulantzi/pais_vasco   alegria_dulantzi/pais_vasco
# 2                amurrio/pais_vasco            amurrio/pais_vasco
# 3                amurrio/pais_vasco            amurrio/pais_vasco
# 4                amurrio/pais_vasco            amurrio/pais_vasco
# ...                             ...                           ...
# 15446                 alagon/aragon                 alagon/aragon
# 15447                  zuera/aragon                  zuera/aragon
# 15448                   asin/aragon                   asin/aragon
# 15449           piedratajada/aragon           piedratajada/aragon
# 15450  villamayor_de_gallego/aragon  villamayor_de_gallego/aragon
#
#                    cities/province_es province_es/ccaa_es  province_es/ccaa  \
# 0              alegria_dulantzi/alava    alava/pais_vasco  alava/pais_vasco
# 1              alegria_dulantzi/alava    alava/pais_vasco  alava/pais_vasco
# 2                       amurrio/alava    alava/pais_vasco  alava/pais_vasco
# 3                       amurrio/alava    alava/pais_vasco  alava/pais_vasco
# 4                       amurrio/alava    alava/pais_vasco  alava/pais_vasco
# ...                               ...                 ...               ...
# 15446                 alagon/zaragoza     zaragoza/aragon   zaragoza/aragon
# 15447                  zuera/zaragoza     zaragoza/aragon   zaragoza/aragon
# 15448                   asin/zaragoza     zaragoza/aragon   zaragoza/aragon
# 15449           piedratajada/zaragoza     zaragoza/aragon   zaragoza/aragon
# 15450  villamayor_de_gallego/zaragoza     zaragoza/aragon   zaragoza/aragon
#
#        province/ccaa_es     province/ccaa  Total: Millones vehículos-km  \
# 0      araba/pais_vasco  araba/pais_vasco                       1869.30
# 1      araba/pais_vasco  araba/pais_vasco                       1869.30
# 2      araba/pais_vasco  araba/pais_vasco                       1869.30
# 3      araba/pais_vasco  araba/pais_vasco                       1869.30
# 4      araba/pais_vasco  araba/pais_vasco                       1869.30
# ...                 ...               ...                           ...
# 15446   zaragoza/aragon   zaragoza/aragon                       4539.27
# 15447   zaragoza/aragon   zaragoza/aragon                       4539.27
# 15448   zaragoza/aragon   zaragoza/aragon                       4539.27
# 15449   zaragoza/aragon   zaragoza/aragon                       4539.27
# 15450   zaragoza/aragon   zaragoza/aragon                       4539.27
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15446                             0.983211                        NaN
# 15447                             0.983211                        NaN
# 15448                             0.983211                        NaN
# 15449                             0.983211                        NaN
# 15450                             0.983211                        NaN
#
#        Calidad_Cobertura_fija&movil_%  accessibility_mean
# 0                               65.00           18.406372
# 1                               65.00           18.406372
# 2                               62.75           18.406372
# 3                               62.75           18.406372
# 4                               62.75           18.406372
# ...                               ...                 ...
# 15446                          100.00           62.648308
# 15447                           88.75           62.648308
# 15448                           52.50           62.648308
# 15449                           22.50           62.648308
# 15450                           77.50           62.648308
#
# [14593 rows x 22 columns]

# %%
estaciones = pd.read_csv('recursos_estaciones_renfe_clean.csv',index_col=None)
estaciones
# Out:
#                   poblacion  numero_estaciones ave cercanias feve
# 0                    madrid                 39  SI        SI   NO
# 1                     siero                 17  NO        SI   SI
# 2                    oviedo                 15  NO        SI   SI
# 3                    bilbao                 14  NO        SI   SI
# 4                 cartagena                 12  NO        NO   SI
# ..                      ...                ...  ..       ...  ...
# 894                 alcover                  1  NO        NO   NO
# 895                aldea_l_                  1  NO        NO   NO
# 896  sant_marti_sesgueioles                  1  NO        NO   NO
# 897                  cheste                  1  NO        SI   NO
# 898              cocentaina                  1  NO        NO   NO
#
# [899 rows x 5 columns]

# %%
union = pd.merge(union, estaciones, left_on='cities_es',right_on='poblacion', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15468     52001       52004           melilla           melilla     melilla
# 15469     52001       52005           melilla           melilla     melilla
# 15470     52001       52005           melilla           melilla     melilla
# 15471     52001       52006           melilla           melilla     melilla
# 15472     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa   cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1        araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2        araba  pais_vasco  pais_vasco           amurrio/alava
# 3        araba  pais_vasco  pais_vasco           amurrio/alava
# 4        araba  pais_vasco  pais_vasco           amurrio/alava
# ...        ...         ...         ...                     ...
# 15468  melilla     melilla     melilla         melilla/melilla
# 15469  melilla     melilla     melilla         melilla/melilla
# 15470  melilla     melilla     melilla         melilla/melilla
# 15471  melilla     melilla     melilla         melilla/melilla
# 15472  melilla     melilla     melilla         melilla/melilla
#
#            cities_es/province            cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2               amurrio/araba           amurrio/pais_vasco
# 3               amurrio/araba           amurrio/pais_vasco
# 4               amurrio/araba           amurrio/pais_vasco
# ...                       ...                          ...
# 15468         melilla/melilla              melilla/melilla
# 15469         melilla/melilla              melilla/melilla
# 15470         melilla/melilla              melilla/melilla
# 15471         melilla/melilla              melilla/melilla
# 15472         melilla/melilla              melilla/melilla
#
#                     cities_es/ccaa      cities/province_es  \
# 0      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 2               amurrio/pais_vasco           amurrio/alava
# 3               amurrio/pais_vasco           amurrio/alava
# 4               amurrio/pais_vasco           amurrio/alava
# ...                            ...                     ...
# 15468              melilla/melilla         melilla/melilla
# 15469              melilla/melilla         melilla/melilla
# 15470              melilla/melilla         melilla/melilla
# 15471              melilla/melilla         melilla/melilla
# 15472              melilla/melilla         melilla/melilla
#
#       province_es/ccaa_es  province_es/ccaa  province/ccaa_es  \
# 0        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 1        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 2        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 3        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 4        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# ...                   ...               ...               ...
# 15468     melilla/melilla   melilla/melilla   melilla/melilla
# 15469     melilla/melilla   melilla/melilla   melilla/melilla
# 15470     melilla/melilla   melilla/melilla   melilla/melilla
# 15471     melilla/melilla   melilla/melilla   melilla/melilla
# 15472     melilla/melilla   melilla/melilla   melilla/melilla
#
#           province/ccaa  Total: Millones vehículos-km  \
# 0      araba/pais_vasco                        1869.3
# 1      araba/pais_vasco                        1869.3
# 2      araba/pais_vasco                        1869.3
# 3      araba/pais_vasco                        1869.3
# 4      araba/pais_vasco                        1869.3
# ...                 ...                           ...
# 15468   melilla/melilla                           0.0
# 15469   melilla/melilla                           0.0
# 15470   melilla/melilla                           0.0
# 15471   melilla/melilla                           0.0
# 15472   melilla/melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15468                                  NaN                        NaN
# 15469                                  NaN                        NaN
# 15470                                  NaN                        NaN
# 15471                                  NaN                        NaN
# 15472                                  NaN                        NaN
#
#        Calidad_Cobertura_fija&movil_%  accessibility_mean         poblacion  \
# 0                               65.00           18.406372  alegria_dulantzi
# 1                               65.00           18.406372  alegria_dulantzi
# 2                               62.75           18.406372           amurrio
# 3                               62.75           18.406372           amurrio
# 4                               62.75           18.406372           amurrio
# ...                               ...                 ...               ...
# 15468                          100.00                 NaN               NaN
# 15469                          100.00                 NaN               NaN
# 15470                          100.00                 NaN               NaN
# 15471                          100.00                 NaN               NaN
# 15472                          100.00                 NaN               NaN
#
#        numero_estaciones  ave cercanias feve
# 0                    1.0   NO        NO   NO
# 1                    1.0   NO        NO   NO
# 2                    4.0   NO        SI   NO
# 3                    4.0   NO        SI   NO
# 4                    4.0   NO        SI   NO
# ...                  ...  ...       ...  ...
# 15468                NaN  NaN       NaN  NaN
# 15469                NaN  NaN       NaN  NaN
# 15470                NaN  NaN       NaN  NaN
# 15471                NaN  NaN       NaN  NaN
# 15472                NaN  NaN       NaN  NaN
#
# [15473 rows x 27 columns]

# %%
union[union['numero_estaciones']>0]
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15443     50297       50017          zaragoza          zaragoza    zaragoza
# 15444     50297       50008          zaragoza          zaragoza    zaragoza
# 15445     50298       50800             zuera             zuera    zaragoza
# 15446     50298       50830            alagon            alagon    zaragoza
# 15447     50298       50810             zuera             zuera    zaragoza
#
#        province     ccaa_es        ccaa   cities_es/province_es  \
# 0         araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 1         araba  pais_vasco  pais_vasco  alegria_dulantzi/alava
# 2         araba  pais_vasco  pais_vasco           amurrio/alava
# 3         araba  pais_vasco  pais_vasco           amurrio/alava
# 4         araba  pais_vasco  pais_vasco           amurrio/alava
# ...         ...         ...         ...                     ...
# 15443  zaragoza      aragon      aragon       zaragoza/zaragoza
# 15444  zaragoza      aragon      aragon       zaragoza/zaragoza
# 15445  zaragoza      aragon      aragon          zuera/zaragoza
# 15446  zaragoza      aragon      aragon         alagon/zaragoza
# 15447  zaragoza      aragon      aragon          zuera/zaragoza
#
#            cities_es/province            cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba  alegria_dulantzi/pais_vasco
# 2               amurrio/araba           amurrio/pais_vasco
# 3               amurrio/araba           amurrio/pais_vasco
# 4               amurrio/araba           amurrio/pais_vasco
# ...                       ...                          ...
# 15443       zaragoza/zaragoza              zaragoza/aragon
# 15444       zaragoza/zaragoza              zaragoza/aragon
# 15445          zuera/zaragoza                 zuera/aragon
# 15446         alagon/zaragoza                alagon/aragon
# 15447          zuera/zaragoza                 zuera/aragon
#
#                     cities_es/ccaa      cities/province_es  \
# 0      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco  alegria_dulantzi/alava
# 2               amurrio/pais_vasco           amurrio/alava
# 3               amurrio/pais_vasco           amurrio/alava
# 4               amurrio/pais_vasco           amurrio/alava
# ...                            ...                     ...
# 15443              zaragoza/aragon       zaragoza/zaragoza
# 15444              zaragoza/aragon       zaragoza/zaragoza
# 15445                 zuera/aragon          zuera/zaragoza
# 15446                alagon/aragon         alagon/zaragoza
# 15447                 zuera/aragon          zuera/zaragoza
#
#       province_es/ccaa_es  province_es/ccaa  province/ccaa_es  \
# 0        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 1        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 2        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 3        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# 4        alava/pais_vasco  alava/pais_vasco  araba/pais_vasco
# ...                   ...               ...               ...
# 15443     zaragoza/aragon   zaragoza/aragon   zaragoza/aragon
# 15444     zaragoza/aragon   zaragoza/aragon   zaragoza/aragon
# 15445     zaragoza/aragon   zaragoza/aragon   zaragoza/aragon
# 15446     zaragoza/aragon   zaragoza/aragon   zaragoza/aragon
# 15447     zaragoza/aragon   zaragoza/aragon   zaragoza/aragon
#
#           province/ccaa  Total: Millones vehículos-km  \
# 0      araba/pais_vasco                       1869.30
# 1      araba/pais_vasco                       1869.30
# 2      araba/pais_vasco                       1869.30
# 3      araba/pais_vasco                       1869.30
# 4      araba/pais_vasco                       1869.30
# ...                 ...                           ...
# 15443   zaragoza/aragon                       4539.27
# 15444   zaragoza/aragon                       4539.27
# 15445   zaragoza/aragon                       4539.27
# 15446   zaragoza/aragon                       4539.27
# 15447   zaragoza/aragon                       4539.27
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15443                             0.983211                        1.0
# 15444                             0.983211                        1.0
# 15445                             0.983211                        NaN
# 15446                             0.983211                        NaN
# 15447                             0.983211                        NaN
#
#        Calidad_Cobertura_fija&movil_%  accessibility_mean         poblacion  \
# 0                               65.00           18.406372  alegria_dulantzi
# 1                               65.00           18.406372  alegria_dulantzi
# 2                               62.75           18.406372           amurrio
# 3                               62.75           18.406372           amurrio
# 4                               62.75           18.406372           amurrio
# ...                               ...                 ...               ...
# 15443                           96.00           62.648308          zaragoza
# 15444                           96.00           62.648308          zaragoza
# 15445                           88.75           62.648308             zuera
# 15446                          100.00           62.648308            alagon
# 15447                           88.75           62.648308             zuera
#
#        numero_estaciones ave cercanias feve
# 0                    1.0  NO        NO   NO
# 1                    1.0  NO        NO   NO
# 2                    4.0  NO        SI   NO
# 3                    4.0  NO        SI   NO
# 4                    4.0  NO        SI   NO
# ...                  ...  ..       ...  ...
# 15443                5.0  SI        SI   NO
# 15444                5.0  SI        SI   NO
# 15445                1.0  NO        NO   NO
# 15446                1.0  NO        NO   NO
# 15447                1.0  NO        NO   NO
#
# [3085 rows x 27 columns]

# %%
estaciones.shape
# Out:
# (899, 5)

# %%
union['numero_estaciones'] = union['numero_estaciones'].fillna(0)
union['ave'] = union['ave'].fillna('NO')
union['cercanias'] = union['cercanias'].fillna('NO')
union['feve'] = union['feve'].fillna('NO')
union.head(20)
# Out:
#     ine_code postal_code            cities_es               cities  \
# 0       1001       01240     alegria_dulantzi     alegria_dulantzi
# 1       1001       01193     alegria_dulantzi     alegria_dulantzi
# 2       1002       01450              amurrio              amurrio
# 3       1002       01468              amurrio              amurrio
# 4       1002       01470              amurrio              amurrio
# 5       1003       01160              aramaio              aramaio
# 6       1003       01165              aramaio              aramaio
# 7       1003       01169              aramaio              aramaio
# 8       1004       01474           artziniega           artziniega
# 9       1004       01478           artziniega           artziniega
# 10      1006       01211              arminon              arminon
# 11      1006       01220              arminon              arminon
# 12      1008       01510  arratzua_ubarrundia  arratzua_ubarrundia
# 13      1008       01520  arratzua_ubarrundia  arratzua_ubarrundia
# 14      1009       01250            asparrena            asparrena
# 15      1009       01260            asparrena            asparrena
# 16      1009       01208            asparrena            asparrena
# 17      1010       01408                ayala                aiara
# 18      1010       01470              amurrio              amurrio
# 19      1010       01476                ayala                aiara
#
#    province_es province     ccaa_es        ccaa      cities_es/province_es  \
# 0        alava    araba  pais_vasco  pais_vasco     alegria_dulantzi/alava
# 1        alava    araba  pais_vasco  pais_vasco     alegria_dulantzi/alava
# 2        alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 3        alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 4        alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 5        alava    araba  pais_vasco  pais_vasco              aramaio/alava
# 6        alava    araba  pais_vasco  pais_vasco              aramaio/alava
# 7        alava    araba  pais_vasco  pais_vasco              aramaio/alava
# 8        alava    araba  pais_vasco  pais_vasco           artziniega/alava
# 9        alava    araba  pais_vasco  pais_vasco           artziniega/alava
# 10       alava    araba  pais_vasco  pais_vasco              arminon/alava
# 11       alava    araba  pais_vasco  pais_vasco              arminon/alava
# 12       alava    araba  pais_vasco  pais_vasco  arratzua_ubarrundia/alava
# 13       alava    araba  pais_vasco  pais_vasco  arratzua_ubarrundia/alava
# 14       alava    araba  pais_vasco  pais_vasco            asparrena/alava
# 15       alava    araba  pais_vasco  pais_vasco            asparrena/alava
# 16       alava    araba  pais_vasco  pais_vasco            asparrena/alava
# 17       alava    araba  pais_vasco  pais_vasco                ayala/alava
# 18       alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 19       alava    araba  pais_vasco  pais_vasco                ayala/alava
#
#            cities_es/province               cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba     alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba     alegria_dulantzi/pais_vasco
# 2               amurrio/araba              amurrio/pais_vasco
# 3               amurrio/araba              amurrio/pais_vasco
# 4               amurrio/araba              amurrio/pais_vasco
# 5               aramaio/araba              aramaio/pais_vasco
# 6               aramaio/araba              aramaio/pais_vasco
# 7               aramaio/araba              aramaio/pais_vasco
# 8            artziniega/araba           artziniega/pais_vasco
# 9            artziniega/araba           artziniega/pais_vasco
# 10              arminon/araba              arminon/pais_vasco
# 11              arminon/araba              arminon/pais_vasco
# 12  arratzua_ubarrundia/araba  arratzua_ubarrundia/pais_vasco
# 13  arratzua_ubarrundia/araba  arratzua_ubarrundia/pais_vasco
# 14            asparrena/araba            asparrena/pais_vasco
# 15            asparrena/araba            asparrena/pais_vasco
# 16            asparrena/araba            asparrena/pais_vasco
# 17                ayala/araba                ayala/pais_vasco
# 18              amurrio/araba              amurrio/pais_vasco
# 19                ayala/araba                ayala/pais_vasco
#
#                     cities_es/ccaa         cities/province_es  \
# 0      alegria_dulantzi/pais_vasco     alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco     alegria_dulantzi/alava
# 2               amurrio/pais_vasco              amurrio/alava
# 3               amurrio/pais_vasco              amurrio/alava
# 4               amurrio/pais_vasco              amurrio/alava
# 5               aramaio/pais_vasco              aramaio/alava
# 6               aramaio/pais_vasco              aramaio/alava
# 7               aramaio/pais_vasco              aramaio/alava
# 8            artziniega/pais_vasco           artziniega/alava
# 9            artziniega/pais_vasco           artziniega/alava
# 10              arminon/pais_vasco              arminon/alava
# 11              arminon/pais_vasco              arminon/alava
# 12  arratzua_ubarrundia/pais_vasco  arratzua_ubarrundia/alava
# 13  arratzua_ubarrundia/pais_vasco  arratzua_ubarrundia/alava
# 14            asparrena/pais_vasco            asparrena/alava
# 15            asparrena/pais_vasco            asparrena/alava
# 16            asparrena/pais_vasco            asparrena/alava
# 17                ayala/pais_vasco                aiara/alava
# 18              amurrio/pais_vasco              amurrio/alava
# 19                ayala/pais_vasco                aiara/alava
#
#    province_es/ccaa_es  province_es/ccaa  province/ccaa_es     province/ccaa  \
# 0     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 1     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 2     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 3     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 4     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 5     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 6     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 7     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 8     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 9     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 10    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 11    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 12    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 13    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 14    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 15    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 16    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 17    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 18    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 19    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
#
#     Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                         1869.3                             0.832942
# 1                         1869.3                             0.832942
# 2                         1869.3                             0.832942
# 3                         1869.3                             0.832942
# 4                         1869.3                             0.832942
# 5                         1869.3                             0.832942
# 6                         1869.3                             0.832942
# 7                         1869.3                             0.832942
# 8                         1869.3                             0.832942
# 9                         1869.3                             0.832942
# 10                        1869.3                             0.832942
# 11                        1869.3                             0.832942
# 12                        1869.3                             0.832942
# 13                        1869.3                             0.832942
# 14                        1869.3                             0.832942
# 15                        1869.3                             0.832942
# 16                        1869.3                             0.832942
# 17                        1869.3                             0.832942
# 18                        1869.3                             0.832942
# 19                        1869.3                             0.832942
#
#     bus_based_companies_count  Calidad_Cobertura_fija&movil_%  \
# 0                         NaN                           65.00
# 1                         NaN                           65.00
# 2                         NaN                           62.75
# 3                         NaN                           62.75
# 4                         NaN                           62.75
# 5                         NaN                           62.22
# 6                         NaN                           62.22
# 7                         NaN                           62.22
# 8                         NaN                           62.86
# 9                         NaN                           62.86
# 10                        NaN                           66.67
# 11                        NaN                           66.67
# 12                        NaN                           63.41
# 13                        NaN                           63.41
# 14                        NaN                           58.00
# 15                        NaN                           58.00
# 16                        NaN                           58.00
# 17                        NaN                           59.90
# 18                        NaN                           62.75
# 19                        NaN                           59.90
#
#     accessibility_mean         poblacion  numero_estaciones ave cercanias feve
# 0            18.406372  alegria_dulantzi                1.0  NO        NO   NO
# 1            18.406372  alegria_dulantzi                1.0  NO        NO   NO
# 2            18.406372           amurrio                4.0  NO        SI   NO
# 3            18.406372           amurrio                4.0  NO        SI   NO
# 4            18.406372           amurrio                4.0  NO        SI   NO
# 5            18.406372               NaN                0.0  NO        NO   NO
# 6            18.406372               NaN                0.0  NO        NO   NO
# 7            18.406372               NaN                0.0  NO        NO   NO
# 8            18.406372               NaN                0.0  NO        NO   NO
# 9            18.406372               NaN                0.0  NO        NO   NO
# 10           18.406372               NaN                0.0  NO        NO   NO
# 11           18.406372               NaN                0.0  NO        NO   NO
# 12           18.406372               NaN                0.0  NO        NO   NO
# 13           18.406372               NaN                0.0  NO        NO   NO
# 14           18.406372               NaN                0.0  NO        NO   NO
# 15           18.406372               NaN                0.0  NO        NO   NO
# 16           18.406372               NaN                0.0  NO        NO   NO
# 17           18.406372             ayala                1.0  NO        SI   NO
# 18           18.406372           amurrio                4.0  NO        SI   NO
# 19           18.406372             ayala                1.0  NO        SI   NO

# %%
union.drop('poblacion',axis=1,inplace=True)

# %%
union.head(20)
# Out:
#     ine_code postal_code            cities_es               cities  \
# 0       1001       01240     alegria_dulantzi     alegria_dulantzi
# 1       1001       01193     alegria_dulantzi     alegria_dulantzi
# 2       1002       01450              amurrio              amurrio
# 3       1002       01468              amurrio              amurrio
# 4       1002       01470              amurrio              amurrio
# 5       1003       01160              aramaio              aramaio
# 6       1003       01165              aramaio              aramaio
# 7       1003       01169              aramaio              aramaio
# 8       1004       01474           artziniega           artziniega
# 9       1004       01478           artziniega           artziniega
# 10      1006       01211              arminon              arminon
# 11      1006       01220              arminon              arminon
# 12      1008       01510  arratzua_ubarrundia  arratzua_ubarrundia
# 13      1008       01520  arratzua_ubarrundia  arratzua_ubarrundia
# 14      1009       01250            asparrena            asparrena
# 15      1009       01260            asparrena            asparrena
# 16      1009       01208            asparrena            asparrena
# 17      1010       01408                ayala                aiara
# 18      1010       01470              amurrio              amurrio
# 19      1010       01476                ayala                aiara
#
#    province_es province     ccaa_es        ccaa      cities_es/province_es  \
# 0        alava    araba  pais_vasco  pais_vasco     alegria_dulantzi/alava
# 1        alava    araba  pais_vasco  pais_vasco     alegria_dulantzi/alava
# 2        alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 3        alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 4        alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 5        alava    araba  pais_vasco  pais_vasco              aramaio/alava
# 6        alava    araba  pais_vasco  pais_vasco              aramaio/alava
# 7        alava    araba  pais_vasco  pais_vasco              aramaio/alava
# 8        alava    araba  pais_vasco  pais_vasco           artziniega/alava
# 9        alava    araba  pais_vasco  pais_vasco           artziniega/alava
# 10       alava    araba  pais_vasco  pais_vasco              arminon/alava
# 11       alava    araba  pais_vasco  pais_vasco              arminon/alava
# 12       alava    araba  pais_vasco  pais_vasco  arratzua_ubarrundia/alava
# 13       alava    araba  pais_vasco  pais_vasco  arratzua_ubarrundia/alava
# 14       alava    araba  pais_vasco  pais_vasco            asparrena/alava
# 15       alava    araba  pais_vasco  pais_vasco            asparrena/alava
# 16       alava    araba  pais_vasco  pais_vasco            asparrena/alava
# 17       alava    araba  pais_vasco  pais_vasco                ayala/alava
# 18       alava    araba  pais_vasco  pais_vasco              amurrio/alava
# 19       alava    araba  pais_vasco  pais_vasco                ayala/alava
#
#            cities_es/province               cities_es/ccaa_es  \
# 0      alegria_dulantzi/araba     alegria_dulantzi/pais_vasco
# 1      alegria_dulantzi/araba     alegria_dulantzi/pais_vasco
# 2               amurrio/araba              amurrio/pais_vasco
# 3               amurrio/araba              amurrio/pais_vasco
# 4               amurrio/araba              amurrio/pais_vasco
# 5               aramaio/araba              aramaio/pais_vasco
# 6               aramaio/araba              aramaio/pais_vasco
# 7               aramaio/araba              aramaio/pais_vasco
# 8            artziniega/araba           artziniega/pais_vasco
# 9            artziniega/araba           artziniega/pais_vasco
# 10              arminon/araba              arminon/pais_vasco
# 11              arminon/araba              arminon/pais_vasco
# 12  arratzua_ubarrundia/araba  arratzua_ubarrundia/pais_vasco
# 13  arratzua_ubarrundia/araba  arratzua_ubarrundia/pais_vasco
# 14            asparrena/araba            asparrena/pais_vasco
# 15            asparrena/araba            asparrena/pais_vasco
# 16            asparrena/araba            asparrena/pais_vasco
# 17                ayala/araba                ayala/pais_vasco
# 18              amurrio/araba              amurrio/pais_vasco
# 19                ayala/araba                ayala/pais_vasco
#
#                     cities_es/ccaa         cities/province_es  \
# 0      alegria_dulantzi/pais_vasco     alegria_dulantzi/alava
# 1      alegria_dulantzi/pais_vasco     alegria_dulantzi/alava
# 2               amurrio/pais_vasco              amurrio/alava
# 3               amurrio/pais_vasco              amurrio/alava
# 4               amurrio/pais_vasco              amurrio/alava
# 5               aramaio/pais_vasco              aramaio/alava
# 6               aramaio/pais_vasco              aramaio/alava
# 7               aramaio/pais_vasco              aramaio/alava
# 8            artziniega/pais_vasco           artziniega/alava
# 9            artziniega/pais_vasco           artziniega/alava
# 10              arminon/pais_vasco              arminon/alava
# 11              arminon/pais_vasco              arminon/alava
# 12  arratzua_ubarrundia/pais_vasco  arratzua_ubarrundia/alava
# 13  arratzua_ubarrundia/pais_vasco  arratzua_ubarrundia/alava
# 14            asparrena/pais_vasco            asparrena/alava
# 15            asparrena/pais_vasco            asparrena/alava
# 16            asparrena/pais_vasco            asparrena/alava
# 17                ayala/pais_vasco                aiara/alava
# 18              amurrio/pais_vasco              amurrio/alava
# 19                ayala/pais_vasco                aiara/alava
#
#    province_es/ccaa_es  province_es/ccaa  province/ccaa_es     province/ccaa  \
# 0     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 1     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 2     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 3     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 4     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 5     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 6     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 7     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 8     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 9     alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 10    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 11    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 12    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 13    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 14    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 15    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 16    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 17    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 18    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
# 19    alava/pais_vasco  alava/pais_vasco  araba/pais_vasco  araba/pais_vasco
#
#     Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                         1869.3                             0.832942
# 1                         1869.3                             0.832942
# 2                         1869.3                             0.832942
# 3                         1869.3                             0.832942
# 4                         1869.3                             0.832942
# 5                         1869.3                             0.832942
# 6                         1869.3                             0.832942
# 7                         1869.3                             0.832942
# 8                         1869.3                             0.832942
# 9                         1869.3                             0.832942
# 10                        1869.3                             0.832942
# 11                        1869.3                             0.832942
# 12                        1869.3                             0.832942
# 13                        1869.3                             0.832942
# 14                        1869.3                             0.832942
# 15                        1869.3                             0.832942
# 16                        1869.3                             0.832942
# 17                        1869.3                             0.832942
# 18                        1869.3                             0.832942
# 19                        1869.3                             0.832942
#
#     bus_based_companies_count  Calidad_Cobertura_fija&movil_%  \
# 0                         NaN                           65.00
# 1                         NaN                           65.00
# 2                         NaN                           62.75
# 3                         NaN                           62.75
# 4                         NaN                           62.75
# 5                         NaN                           62.22
# 6                         NaN                           62.22
# 7                         NaN                           62.22
# 8                         NaN                           62.86
# 9                         NaN                           62.86
# 10                        NaN                           66.67
# 11                        NaN                           66.67
# 12                        NaN                           63.41
# 13                        NaN                           63.41
# 14                        NaN                           58.00
# 15                        NaN                           58.00
# 16                        NaN                           58.00
# 17                        NaN                           59.90
# 18                        NaN                           62.75
# 19                        NaN                           59.90
#
#     accessibility_mean  numero_estaciones ave cercanias feve
# 0            18.406372                1.0  NO        NO   NO
# 1            18.406372                1.0  NO        NO   NO
# 2            18.406372                4.0  NO        SI   NO
# 3            18.406372                4.0  NO        SI   NO
# 4            18.406372                4.0  NO        SI   NO
# 5            18.406372                0.0  NO        NO   NO
# 6            18.406372                0.0  NO        NO   NO
# 7            18.406372                0.0  NO        NO   NO
# 8            18.406372                0.0  NO        NO   NO
# 9            18.406372                0.0  NO        NO   NO
# 10           18.406372                0.0  NO        NO   NO
# 11           18.406372                0.0  NO        NO   NO
# 12           18.406372                0.0  NO        NO   NO
# 13           18.406372                0.0  NO        NO   NO
# 14           18.406372                0.0  NO        NO   NO
# 15           18.406372                0.0  NO        NO   NO
# 16           18.406372                0.0  NO        NO   NO
# 17           18.406372                1.0  NO        SI   NO
# 18           18.406372                4.0  NO        SI   NO
# 19           18.406372                1.0  NO        SI   NO
