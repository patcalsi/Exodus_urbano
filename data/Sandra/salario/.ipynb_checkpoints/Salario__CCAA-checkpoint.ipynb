# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import datasets
from io import StringIO
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import metrics
# %matplotlib inline

# %%
Salarios = pd.read_csv('Salarios_2014.csv', sep=';', skiprows = 2)

# %%
Salarios
# Out:
#     Código                    Etiqueta  \
# 0       61                   Andalucía
# 1       62                      Aragón
# 2       63      Principado de Asturias
# 3       64               Illes Balears
# 4       65                    Canarias
# 5       66                   Cantabria
# 6       67             Castilla y León
# 7       68          Castilla-La Mancha
# 8       69          Cataluña/Catalunya
# 9       70                 Extremadura
# 10      71                     Galicia
# 11      72         Comunidad de Madrid
# 12      73            Región de Murcia
# 13      74  Comunidad Foral de Navarra
# 14      75          País Vasco/Euskadi
# 15      76                    La Rioja
# 16      77        Comunitat Valenciana
# 17      78             Ciudad de Ceuta
# 18      79           Ciudad de Melilla
#
#     Ganancia media anual por salario mínimo interprofesional (serie) 2014
# 0                                                2.31
# 1                                                2.45
# 2                                                2.44
# 3                                                2.36
# 4                                                2.15
# 5                                                2.35
# 6                                                2.27
# 7                                                2.29
# 8                                                2.65
# 9                                                2.12
# 10                                               2.24
# 11                                               2.94
# 12                                               2.29
# 13                                               2.73
# 14                                               3.08
# 15                                               2.43
# 16                                               2.28
# 17                                                NaN
# 18                                                NaN

# %%
Salarios.describe()
# Out:
#           Código  \
# count  19.000000
# mean   70.000000
# std     5.627314
# min    61.000000
# 25%    65.500000
# 50%    70.000000
# 75%    74.500000
# max    79.000000
#
#        Ganancia media anual por salario mínimo interprofesional (serie) 2014
# count                                          17.000000
# mean                                            2.434118
# std                                             0.267490
# min                                             2.120000
# 25%                                             2.280000
# 50%                                             2.350000
# 75%                                             2.450000
# max                                             3.080000

# %%
Salarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
# Código                                                                   19 non-null int64
# Etiqueta                                                                 19 non-null object
# Ganancia media anual por salario mínimo interprofesional (serie) 2014    17 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 584.0+ bytes

# %%
# Guardamos:

Salarios.to_csv('Economia_salario_CCAA_2014.csv')
