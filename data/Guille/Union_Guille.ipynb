# %%
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import re   
import locale

# %%
trafico = pd.read_csv('recursos_trafico_carreteras_clean.csv',index_col=0)
trafico.Provincia_name[trafico['Provincia_name']=='a_coruna'] = 'coruna'
trafico[trafico['Provincia_name']=='coruna']
# Out:
#    CCAA_name Provincia_name  Total: Millones vehículos-km  \
# 52   galicia         coruna                        6661.4
#
#     porcentaje_carreteras_ccaa_y_estado
# 52                             0.805714

# %%
maestro = pd.read_csv('maestro_idiomas_ine.csv', index_col = 0, dtype={'postal_code': object})
maestro.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa cities_es/province_es cities_es/province  \
# 0    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 1    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 2    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 3    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 4    araba  pais_vasco  pais_vasco               amurrio            amurrio
#
#   cities_es/ccaa_es    cities_es/ccaa cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 1  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 2           amurrio           amurrio            amurrio               alava
# 3           amurrio           amurrio            amurrio               alava
# 4           amurrio           amurrio            amurrio               alava
#
#   province_es/ccaa province/ccaa_es province/ccaa
# 0            alava            araba         araba
# 1            alava            araba         araba
# 2            alava            araba         araba
# 3            alava            araba         araba
# 4            alava            araba         araba

# %%
union = pd.merge(maestro, trafico, left_on='province_es',right_on='Provincia_name', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15386     52001       52004           melilla           melilla     melilla
# 15387     52001       52005           melilla           melilla     melilla
# 15388     52001       52005           melilla           melilla     melilla
# 15389     52001       52006           melilla           melilla     melilla
# 15390     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 1        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 2        araba  pais_vasco  pais_vasco               amurrio
# 3        araba  pais_vasco  pais_vasco               amurrio
# 4        araba  pais_vasco  pais_vasco               amurrio
# ...        ...         ...         ...                   ...
# 15386  melilla     melilla     melilla               melilla
# 15387  melilla     melilla     melilla               melilla
# 15388  melilla     melilla     melilla               melilla
# 15389  melilla     melilla     melilla               melilla
# 15390  melilla     melilla     melilla               melilla
#
#       cities_es/province cities_es/ccaa_es    cities_es/ccaa  \
# 0       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 1       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 2                amurrio           amurrio           amurrio
# 3                amurrio           amurrio           amurrio
# 4                amurrio           amurrio           amurrio
# ...                  ...               ...               ...
# 15386            melilla           melilla           melilla
# 15387            melilla           melilla           melilla
# 15388            melilla           melilla           melilla
# 15389            melilla           melilla           melilla
# 15390            melilla           melilla           melilla
#
#       cities/province_es province_es/ccaa_es province_es/ccaa  \
# 0       alegria_dulantzi               alava            alava
# 1       alegria_dulantzi               alava            alava
# 2                amurrio               alava            alava
# 3                amurrio               alava            alava
# 4                amurrio               alava            alava
# ...                  ...                 ...              ...
# 15386            melilla             melilla          melilla
# 15387            melilla             melilla          melilla
# 15388            melilla             melilla          melilla
# 15389            melilla             melilla          melilla
# 15390            melilla             melilla          melilla
#
#       province/ccaa_es province/ccaa   CCAA_name Provincia_name  \
# 0                araba         araba  pais_vasco          alava
# 1                araba         araba  pais_vasco          alava
# 2                araba         araba  pais_vasco          alava
# 3                araba         araba  pais_vasco          alava
# 4                araba         araba  pais_vasco          alava
# ...                ...           ...         ...            ...
# 15386          melilla       melilla     melilla        melilla
# 15387          melilla       melilla     melilla        melilla
# 15388          melilla       melilla     melilla        melilla
# 15389          melilla       melilla     melilla        melilla
# 15390          melilla       melilla     melilla        melilla
#
#        Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado
# 0                            1869.3                             0.832942
# 1                            1869.3                             0.832942
# 2                            1869.3                             0.832942
# 3                            1869.3                             0.832942
# 4                            1869.3                             0.832942
# ...                             ...                                  ...
# 15386                           0.0                                  NaN
# 15387                           0.0                                  NaN
# 15388                           0.0                                  NaN
# 15389                           0.0                                  NaN
# 15390                           0.0                                  NaN
#
# [15391 rows x 21 columns]

# %%
union[union['province_es'] != union['Provincia_name']]
# Out:
#        ine_code postal_code cities_es cities province_es province ccaa_es  \
# 134        2003         NaN       NaN    NaN         NaN      NaN     NaN
# 151        2006         NaN       NaN    NaN         NaN      NaN     NaN
# 157        2008         NaN       NaN    NaN         NaN      NaN     NaN
# 165        2011         NaN       NaN    NaN         NaN      NaN     NaN
# 167        2011         NaN       NaN    NaN         NaN      NaN     NaN
# ...         ...         ...       ...    ...         ...      ...     ...
# 15235     50217         NaN       NaN    NaN         NaN      NaN     NaN
# 15259     50238         NaN       NaN    NaN         NaN      NaN     NaN
# 15274     50248         NaN       NaN    NaN         NaN      NaN     NaN
# 15332     50297         NaN       NaN    NaN         NaN      NaN     NaN
# 15342     50297         NaN       NaN    NaN         NaN      NaN     NaN
#
#       ccaa cities_es/province_es cities_es/province cities_es/ccaa_es  \
# 134    NaN                   NaN                NaN               NaN
# 151    NaN                   NaN                NaN               NaN
# 157    NaN                   NaN                NaN               NaN
# 165    NaN                   NaN                NaN               NaN
# 167    NaN                   NaN                NaN               NaN
# ...    ...                   ...                ...               ...
# 15235  NaN                   NaN                NaN               NaN
# 15259  NaN                   NaN                NaN               NaN
# 15274  NaN                   NaN                NaN               NaN
# 15332  NaN                   NaN                NaN               NaN
# 15342  NaN                   NaN                NaN               NaN
#
#       cities_es/ccaa cities/province_es province_es/ccaa_es province_es/ccaa  \
# 134              NaN                NaN                 NaN              NaN
# 151              NaN                NaN                 NaN              NaN
# 157              NaN                NaN                 NaN              NaN
# 165              NaN                NaN                 NaN              NaN
# 167              NaN                NaN                 NaN              NaN
# ...              ...                ...                 ...              ...
# 15235            NaN                NaN                 NaN              NaN
# 15259            NaN                NaN                 NaN              NaN
# 15274            NaN                NaN                 NaN              NaN
# 15332            NaN                NaN                 NaN              NaN
# 15342            NaN                NaN                 NaN              NaN
#
#       province/ccaa_es province/ccaa CCAA_name Provincia_name  \
# 134                NaN           NaN       NaN            NaN
# 151                NaN           NaN       NaN            NaN
# 157                NaN           NaN       NaN            NaN
# 165                NaN           NaN       NaN            NaN
# 167                NaN           NaN       NaN            NaN
# ...                ...           ...       ...            ...
# 15235              NaN           NaN       NaN            NaN
# 15259              NaN           NaN       NaN            NaN
# 15274              NaN           NaN       NaN            NaN
# 15332              NaN           NaN       NaN            NaN
# 15342              NaN           NaN       NaN            NaN
#
#        Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado
# 134                             NaN                                  NaN
# 151                             NaN                                  NaN
# 157                             NaN                                  NaN
# 165                             NaN                                  NaN
# 167                             NaN                                  NaN
# ...                             ...                                  ...
# 15235                           NaN                                  NaN
# 15259                           NaN                                  NaN
# 15274                           NaN                                  NaN
# 15332                           NaN                                  NaN
# 15342                           NaN                                  NaN
#
# [739 rows x 21 columns]

# %%
union[union['province_es'] != union['Provincia_name']].shape
# Out:
# (739, 21)

# %%
union.drop(['CCAA_name', 'Provincia_name'], axis=1, inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa cities_es/province_es cities_es/province  \
# 0    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 1    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 2    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 3    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 4    araba  pais_vasco  pais_vasco               amurrio            amurrio
#
#   cities_es/ccaa_es    cities_es/ccaa cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 1  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 2           amurrio           amurrio            amurrio               alava
# 3           amurrio           amurrio            amurrio               alava
# 4           amurrio           amurrio            amurrio               alava
#
#   province_es/ccaa province/ccaa_es province/ccaa  \
# 0            alava            araba         araba
# 1            alava            araba         araba
# 2            alava            araba         araba
# 3            alava            araba         araba
# 4            alava            araba         araba
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942

# %%
empresas_autobuses = pd.read_csv('recursos_empresas_autobuses_clean.csv',index_col=0)
empresas_autobuses
# Out:
#            Municipio  bus_based_companies_count
# 0          barcelona                          5
# 1            caceres                          3
# 2              soria                          3
# 3               jaen                          3
# 4          salamanca                          3
# ..               ...                        ...
# 72           logrono                          1
# 73  monet_del_valles                          1
# 74              lugo                          1
# 75         catarroja                          1
# 76         santander                          1
#
# [77 rows x 2 columns]

# %%
union = pd.merge(union, empresas_autobuses, left_on='cities_es',right_on='Municipio', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15386     52001       52004           melilla           melilla     melilla
# 15387     52001       52005           melilla           melilla     melilla
# 15388     52001       52005           melilla           melilla     melilla
# 15389     52001       52006           melilla           melilla     melilla
# 15390     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 1        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 2        araba  pais_vasco  pais_vasco               amurrio
# 3        araba  pais_vasco  pais_vasco               amurrio
# 4        araba  pais_vasco  pais_vasco               amurrio
# ...        ...         ...         ...                   ...
# 15386  melilla     melilla     melilla               melilla
# 15387  melilla     melilla     melilla               melilla
# 15388  melilla     melilla     melilla               melilla
# 15389  melilla     melilla     melilla               melilla
# 15390  melilla     melilla     melilla               melilla
#
#       cities_es/province cities_es/ccaa_es    cities_es/ccaa  \
# 0       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 1       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 2                amurrio           amurrio           amurrio
# 3                amurrio           amurrio           amurrio
# 4                amurrio           amurrio           amurrio
# ...                  ...               ...               ...
# 15386            melilla           melilla           melilla
# 15387            melilla           melilla           melilla
# 15388            melilla           melilla           melilla
# 15389            melilla           melilla           melilla
# 15390            melilla           melilla           melilla
#
#       cities/province_es province_es/ccaa_es province_es/ccaa  \
# 0       alegria_dulantzi               alava            alava
# 1       alegria_dulantzi               alava            alava
# 2                amurrio               alava            alava
# 3                amurrio               alava            alava
# 4                amurrio               alava            alava
# ...                  ...                 ...              ...
# 15386            melilla             melilla          melilla
# 15387            melilla             melilla          melilla
# 15388            melilla             melilla          melilla
# 15389            melilla             melilla          melilla
# 15390            melilla             melilla          melilla
#
#       province/ccaa_es province/ccaa  Total: Millones vehículos-km  \
# 0                araba         araba                        1869.3
# 1                araba         araba                        1869.3
# 2                araba         araba                        1869.3
# 3                araba         araba                        1869.3
# 4                araba         araba                        1869.3
# ...                ...           ...                           ...
# 15386          melilla       melilla                           0.0
# 15387          melilla       melilla                           0.0
# 15388          melilla       melilla                           0.0
# 15389          melilla       melilla                           0.0
# 15390          melilla       melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado Municipio  \
# 0                                 0.832942       NaN
# 1                                 0.832942       NaN
# 2                                 0.832942       NaN
# 3                                 0.832942       NaN
# 4                                 0.832942       NaN
# ...                                    ...       ...
# 15386                                  NaN       NaN
# 15387                                  NaN       NaN
# 15388                                  NaN       NaN
# 15389                                  NaN       NaN
# 15390                                  NaN       NaN
#
#        bus_based_companies_count
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 15386                        NaN
# 15387                        NaN
# 15388                        NaN
# 15389                        NaN
# 15390                        NaN
#
# [15391 rows x 21 columns]

# %%
union[union['bus_based_companies_count'] > 0]
# Out:
#        ine_code postal_code cities_es    cities province_es  province  \
# 60         1036       01400    llodio    laudio       alava     araba
# 135        2003       02140  albacete  albacete    albacete  albacete
# 136        2003       02155  albacete  albacete    albacete  albacete
# 137        2003       02328  albacete  albacete    albacete  albacete
# 138        2003       02512  albacete  albacete    albacete  albacete
# ...         ...         ...       ...       ...         ...       ...
# 15358     50297       50014  zaragoza  zaragoza    zaragoza  zaragoza
# 15359     50297       50015  zaragoza  zaragoza    zaragoza  zaragoza
# 15360     50297       50016  zaragoza  zaragoza    zaragoza  zaragoza
# 15361     50297       50017  zaragoza  zaragoza    zaragoza  zaragoza
# 15362     50297       50008  zaragoza  zaragoza    zaragoza  zaragoza
#
#                   ccaa_es                ccaa cities_es/province_es  \
# 60             pais_vasco          pais_vasco                llodio
# 135    castilla_la_mancha  castilla_la_mancha              albacete
# 136    castilla_la_mancha  castilla_la_mancha              albacete
# 137    castilla_la_mancha  castilla_la_mancha              albacete
# 138    castilla_la_mancha  castilla_la_mancha              albacete
# ...                   ...                 ...                   ...
# 15358              aragon              aragon              zaragoza
# 15359              aragon              aragon              zaragoza
# 15360              aragon              aragon              zaragoza
# 15361              aragon              aragon              zaragoza
# 15362              aragon              aragon              zaragoza
#
#       cities_es/province cities_es/ccaa_es cities_es/ccaa cities/province_es  \
# 60                llodio            llodio         llodio             laudio
# 135             albacete          albacete       albacete           albacete
# 136             albacete          albacete       albacete           albacete
# 137             albacete          albacete       albacete           albacete
# 138             albacete          albacete       albacete           albacete
# ...                  ...               ...            ...                ...
# 15358           zaragoza          zaragoza       zaragoza           zaragoza
# 15359           zaragoza          zaragoza       zaragoza           zaragoza
# 15360           zaragoza          zaragoza       zaragoza           zaragoza
# 15361           zaragoza          zaragoza       zaragoza           zaragoza
# 15362           zaragoza          zaragoza       zaragoza           zaragoza
#
#       province_es/ccaa_es province_es/ccaa province/ccaa_es province/ccaa  \
# 60                  alava            alava            araba         araba
# 135              albacete         albacete         albacete      albacete
# 136              albacete         albacete         albacete      albacete
# 137              albacete         albacete         albacete      albacete
# 138              albacete         albacete         albacete      albacete
# ...                   ...              ...              ...           ...
# 15358            zaragoza         zaragoza         zaragoza      zaragoza
# 15359            zaragoza         zaragoza         zaragoza      zaragoza
# 15360            zaragoza         zaragoza         zaragoza      zaragoza
# 15361            zaragoza         zaragoza         zaragoza      zaragoza
# 15362            zaragoza         zaragoza         zaragoza      zaragoza
#
#        Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 60                          1869.30                             0.832942
# 135                         2849.71                             0.872415
# 136                         2849.71                             0.872415
# 137                         2849.71                             0.872415
# 138                         2849.71                             0.872415
# ...                             ...                                  ...
# 15358                       4539.27                             0.983211
# 15359                       4539.27                             0.983211
# 15360                       4539.27                             0.983211
# 15361                       4539.27                             0.983211
# 15362                       4539.27                             0.983211
#
#       Municipio  bus_based_companies_count
# 60       llodio                        1.0
# 135    albacete                        1.0
# 136    albacete                        1.0
# 137    albacete                        1.0
# 138    albacete                        1.0
# ...         ...                        ...
# 15358  zaragoza                        1.0
# 15359  zaragoza                        1.0
# 15360  zaragoza                        1.0
# 15361  zaragoza                        1.0
# 15362  zaragoza                        1.0
#
# [622 rows x 21 columns]

# %%
union.drop('Municipio',axis=1,inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa cities_es/province_es cities_es/province  \
# 0    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 1    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 2    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 3    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 4    araba  pais_vasco  pais_vasco               amurrio            amurrio
#
#   cities_es/ccaa_es    cities_es/ccaa cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 1  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 2           amurrio           amurrio            amurrio               alava
# 3           amurrio           amurrio            amurrio               alava
# 4           amurrio           amurrio            amurrio               alava
#
#   province_es/ccaa province/ccaa_es province/ccaa  \
# 0            alava            araba         araba
# 1            alava            araba         araba
# 2            alava            araba         araba
# 3            alava            araba         araba
# 4            alava            araba         araba
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942
#
#    bus_based_companies_count
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
cobertura_media = pd.read_csv('recursos_cobertura_media_clean.csv',index_col=0)
cobertura_media
# Out:
#      Provinicia              Municipio      Cod ESP  \
# 0         araba       alegria_dulantzi   1001000100
# 1         araba                amurrio   1002000100
# 2         araba                aramaio   1003000100
# 3         araba             artziniega   1004000100
# 4         araba                arminon   1006000100
# ...         ...                    ...          ...
# 8119   zaragoza                   biel  50901000100
# 8120   zaragoza               marracos  50902000100
# 8121   zaragoza  villamayor_de_gallego  50903000100
# 8122      ceuta                  ceuta  51001000100
# 8123    melilla                melilla  52001000300
#
#       Calidad_Cobertura_fija&movil_%
# 0                              65.00
# 1                              62.75
# 2                              62.22
# 3                              62.86
# 4                              66.67
# ...                              ...
# 8119                           25.00
# 8120                           45.00
# 8121                           77.50
# 8122                           72.50
# 8123                          100.00
#
# [8124 rows x 4 columns]

# %%
union = pd.merge(union, cobertura_media, left_on='cities_es',right_on='Municipio', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15468     52001       52004           melilla           melilla     melilla
# 15469     52001       52005           melilla           melilla     melilla
# 15470     52001       52005           melilla           melilla     melilla
# 15471     52001       52006           melilla           melilla     melilla
# 15472     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 1        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 2        araba  pais_vasco  pais_vasco               amurrio
# 3        araba  pais_vasco  pais_vasco               amurrio
# 4        araba  pais_vasco  pais_vasco               amurrio
# ...        ...         ...         ...                   ...
# 15468  melilla     melilla     melilla               melilla
# 15469  melilla     melilla     melilla               melilla
# 15470  melilla     melilla     melilla               melilla
# 15471  melilla     melilla     melilla               melilla
# 15472  melilla     melilla     melilla               melilla
#
#       cities_es/province cities_es/ccaa_es    cities_es/ccaa  \
# 0       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 1       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 2                amurrio           amurrio           amurrio
# 3                amurrio           amurrio           amurrio
# 4                amurrio           amurrio           amurrio
# ...                  ...               ...               ...
# 15468            melilla           melilla           melilla
# 15469            melilla           melilla           melilla
# 15470            melilla           melilla           melilla
# 15471            melilla           melilla           melilla
# 15472            melilla           melilla           melilla
#
#       cities/province_es province_es/ccaa_es province_es/ccaa  \
# 0       alegria_dulantzi               alava            alava
# 1       alegria_dulantzi               alava            alava
# 2                amurrio               alava            alava
# 3                amurrio               alava            alava
# 4                amurrio               alava            alava
# ...                  ...                 ...              ...
# 15468            melilla             melilla          melilla
# 15469            melilla             melilla          melilla
# 15470            melilla             melilla          melilla
# 15471            melilla             melilla          melilla
# 15472            melilla             melilla          melilla
#
#       province/ccaa_es province/ccaa  Total: Millones vehículos-km  \
# 0                araba         araba                        1869.3
# 1                araba         araba                        1869.3
# 2                araba         araba                        1869.3
# 3                araba         araba                        1869.3
# 4                araba         araba                        1869.3
# ...                ...           ...                           ...
# 15468          melilla       melilla                           0.0
# 15469          melilla       melilla                           0.0
# 15470          melilla       melilla                           0.0
# 15471          melilla       melilla                           0.0
# 15472          melilla       melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15468                                  NaN                        NaN
# 15469                                  NaN                        NaN
# 15470                                  NaN                        NaN
# 15471                                  NaN                        NaN
# 15472                                  NaN                        NaN
#
#       Provinicia         Municipio       Cod ESP  \
# 0          araba  alegria_dulantzi  1.001000e+09
# 1          araba  alegria_dulantzi  1.001000e+09
# 2          araba           amurrio  1.002000e+09
# 3          araba           amurrio  1.002000e+09
# 4          araba           amurrio  1.002000e+09
# ...          ...               ...           ...
# 15468    melilla           melilla  5.200100e+10
# 15469    melilla           melilla  5.200100e+10
# 15470    melilla           melilla  5.200100e+10
# 15471    melilla           melilla  5.200100e+10
# 15472    melilla           melilla  5.200100e+10
#
#        Calidad_Cobertura_fija&movil_%
# 0                               65.00
# 1                               65.00
# 2                               62.75
# 3                               62.75
# 4                               62.75
# ...                               ...
# 15468                          100.00
# 15469                          100.00
# 15470                          100.00
# 15471                          100.00
# 15472                          100.00
#
# [15473 rows x 24 columns]

# %%
union[union['Calidad_Cobertura_fija&movil_%'] > 0]
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15468     52001       52004           melilla           melilla     melilla
# 15469     52001       52005           melilla           melilla     melilla
# 15470     52001       52005           melilla           melilla     melilla
# 15471     52001       52006           melilla           melilla     melilla
# 15472     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 1        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 2        araba  pais_vasco  pais_vasco               amurrio
# 3        araba  pais_vasco  pais_vasco               amurrio
# 4        araba  pais_vasco  pais_vasco               amurrio
# ...        ...         ...         ...                   ...
# 15468  melilla     melilla     melilla               melilla
# 15469  melilla     melilla     melilla               melilla
# 15470  melilla     melilla     melilla               melilla
# 15471  melilla     melilla     melilla               melilla
# 15472  melilla     melilla     melilla               melilla
#
#       cities_es/province cities_es/ccaa_es    cities_es/ccaa  \
# 0       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 1       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 2                amurrio           amurrio           amurrio
# 3                amurrio           amurrio           amurrio
# 4                amurrio           amurrio           amurrio
# ...                  ...               ...               ...
# 15468            melilla           melilla           melilla
# 15469            melilla           melilla           melilla
# 15470            melilla           melilla           melilla
# 15471            melilla           melilla           melilla
# 15472            melilla           melilla           melilla
#
#       cities/province_es province_es/ccaa_es province_es/ccaa  \
# 0       alegria_dulantzi               alava            alava
# 1       alegria_dulantzi               alava            alava
# 2                amurrio               alava            alava
# 3                amurrio               alava            alava
# 4                amurrio               alava            alava
# ...                  ...                 ...              ...
# 15468            melilla             melilla          melilla
# 15469            melilla             melilla          melilla
# 15470            melilla             melilla          melilla
# 15471            melilla             melilla          melilla
# 15472            melilla             melilla          melilla
#
#       province/ccaa_es province/ccaa  Total: Millones vehículos-km  \
# 0                araba         araba                        1869.3
# 1                araba         araba                        1869.3
# 2                araba         araba                        1869.3
# 3                araba         araba                        1869.3
# 4                araba         araba                        1869.3
# ...                ...           ...                           ...
# 15468          melilla       melilla                           0.0
# 15469          melilla       melilla                           0.0
# 15470          melilla       melilla                           0.0
# 15471          melilla       melilla                           0.0
# 15472          melilla       melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15468                                  NaN                        NaN
# 15469                                  NaN                        NaN
# 15470                                  NaN                        NaN
# 15471                                  NaN                        NaN
# 15472                                  NaN                        NaN
#
#       Provinicia         Municipio       Cod ESP  \
# 0          araba  alegria_dulantzi  1.001000e+09
# 1          araba  alegria_dulantzi  1.001000e+09
# 2          araba           amurrio  1.002000e+09
# 3          araba           amurrio  1.002000e+09
# 4          araba           amurrio  1.002000e+09
# ...          ...               ...           ...
# 15468    melilla           melilla  5.200100e+10
# 15469    melilla           melilla  5.200100e+10
# 15470    melilla           melilla  5.200100e+10
# 15471    melilla           melilla  5.200100e+10
# 15472    melilla           melilla  5.200100e+10
#
#        Calidad_Cobertura_fija&movil_%
# 0                               65.00
# 1                               65.00
# 2                               62.75
# 3                               62.75
# 4                               62.75
# ...                               ...
# 15468                          100.00
# 15469                          100.00
# 15470                          100.00
# 15471                          100.00
# 15472                          100.00
#
# [13782 rows x 24 columns]

# %%
union.shape
# Out:
# (15473, 24)

# %% [markdown]
# La gran mayoría de municipios coinciden. ON AND ON

# %%
union.drop(['Municipio','Cod ESP','Provinicia'],axis=1,inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa cities_es/province_es cities_es/province  \
# 0    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 1    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 2    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 3    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 4    araba  pais_vasco  pais_vasco               amurrio            amurrio
#
#   cities_es/ccaa_es    cities_es/ccaa cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 1  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 2           amurrio           amurrio            amurrio               alava
# 3           amurrio           amurrio            amurrio               alava
# 4           amurrio           amurrio            amurrio               alava
#
#   province_es/ccaa province/ccaa_es province/ccaa  \
# 0            alava            araba         araba
# 1            alava            araba         araba
# 2            alava            araba         araba
# 3            alava            araba         araba
# 4            alava            araba         araba
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942
#
#    bus_based_companies_count  Calidad_Cobertura_fija&movil_%
# 0                        NaN                           65.00
# 1                        NaN                           65.00
# 2                        NaN                           62.75
# 3                        NaN                           62.75
# 4                        NaN                           62.75

# %%
accesibilidad_media_provincial = pd.read_csv('recursos_accesibilidad_ciudades_ccaa.csv',index_col=0)
accesibilidad_media_provincial
# Out:
#     GID_0 NAME_0     GID_1                      NAME_1  accessibility_mean
# 853   ESP  Spain   ESP.1_1                   andalucia           51.600938
# 854   ESP  Spain   ESP.2_1                      aragon           62.648308
# 855   ESP  Spain   ESP.3_1                   cantabria           30.750593
# 856   ESP  Spain   ESP.4_1          castilla_la_mancha           58.622329
# 857   ESP  Spain   ESP.5_1             castilla_y_leon           52.068456
# 858   ESP  Spain   ESP.6_1                    cataluna           37.202517
# 859   ESP  Spain   ESP.7_1             ceuta_y_melilla            5.638889
# 860   ESP  Spain   ESP.8_1         comunidad_de_madrid           17.292365
# 861   ESP  Spain   ESP.9_1  comunidad_foral_de_navarra           30.136247
# 862   ESP  Spain  ESP.10_1        comunidad_valenciana           32.981396
# 863   ESP  Spain  ESP.11_1                 extremadura           63.744231
# 864   ESP  Spain  ESP.12_1                     galicia           42.585970
# 865   ESP  Spain  ESP.13_1              islas_baleares           47.560710
# 866   ESP  Spain  ESP.14_1              islas_canarias           86.588445
# 867   ESP  Spain  ESP.15_1                    la_rioja           36.967848
# 868   ESP  Spain  ESP.16_1                  pais_vasco           18.406372
# 869   ESP  Spain  ESP.17_1      principado_de_asturias           43.839053
# 870   ESP  Spain  ESP.18_1            region_de_murcia           35.040477

# %%
accesibilidad_media_provincial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 853 to 870
# Data columns (total 5 columns):
# GID_0                 18 non-null object
# NAME_0                18 non-null object
# GID_1                 18 non-null object
# NAME_1                18 non-null object
# accessibility_mean    18 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 864.0+ bytes

# %% [markdown]
# Time it takes to travel to the nearest urban center in 2015. Units are minutes, hours, days, and months via surface transit.
# An urban center is defined as a contiguous area with 1,500 or more inhabitants per km² or a majority of built-up land cover coincident with a population center of at least 50,000 inhabitants.

# %%
union = pd.merge(union, accesibilidad_media_provincial, left_on='ccaa_es',right_on='NAME_1', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 15468     52001       52004           melilla           melilla     melilla
# 15469     52001       52005           melilla           melilla     melilla
# 15470     52001       52005           melilla           melilla     melilla
# 15471     52001       52006           melilla           melilla     melilla
# 15472     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 1        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 2        araba  pais_vasco  pais_vasco               amurrio
# 3        araba  pais_vasco  pais_vasco               amurrio
# 4        araba  pais_vasco  pais_vasco               amurrio
# ...        ...         ...         ...                   ...
# 15468  melilla     melilla     melilla               melilla
# 15469  melilla     melilla     melilla               melilla
# 15470  melilla     melilla     melilla               melilla
# 15471  melilla     melilla     melilla               melilla
# 15472  melilla     melilla     melilla               melilla
#
#       cities_es/province cities_es/ccaa_es    cities_es/ccaa  \
# 0       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 1       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 2                amurrio           amurrio           amurrio
# 3                amurrio           amurrio           amurrio
# 4                amurrio           amurrio           amurrio
# ...                  ...               ...               ...
# 15468            melilla           melilla           melilla
# 15469            melilla           melilla           melilla
# 15470            melilla           melilla           melilla
# 15471            melilla           melilla           melilla
# 15472            melilla           melilla           melilla
#
#       cities/province_es province_es/ccaa_es province_es/ccaa  \
# 0       alegria_dulantzi               alava            alava
# 1       alegria_dulantzi               alava            alava
# 2                amurrio               alava            alava
# 3                amurrio               alava            alava
# 4                amurrio               alava            alava
# ...                  ...                 ...              ...
# 15468            melilla             melilla          melilla
# 15469            melilla             melilla          melilla
# 15470            melilla             melilla          melilla
# 15471            melilla             melilla          melilla
# 15472            melilla             melilla          melilla
#
#       province/ccaa_es province/ccaa  Total: Millones vehículos-km  \
# 0                araba         araba                        1869.3
# 1                araba         araba                        1869.3
# 2                araba         araba                        1869.3
# 3                araba         araba                        1869.3
# 4                araba         araba                        1869.3
# ...                ...           ...                           ...
# 15468          melilla       melilla                           0.0
# 15469          melilla       melilla                           0.0
# 15470          melilla       melilla                           0.0
# 15471          melilla       melilla                           0.0
# 15472          melilla       melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15468                                  NaN                        NaN
# 15469                                  NaN                        NaN
# 15470                                  NaN                        NaN
# 15471                                  NaN                        NaN
# 15472                                  NaN                        NaN
#
#        Calidad_Cobertura_fija&movil_% GID_0_x NAME_0_x GID_1_x NAME_1_x  \
# 0                               65.00     NaN      NaN     NaN      NaN
# 1                               65.00     NaN      NaN     NaN      NaN
# 2                               62.75     NaN      NaN     NaN      NaN
# 3                               62.75     NaN      NaN     NaN      NaN
# 4                               62.75     NaN      NaN     NaN      NaN
# ...                               ...     ...      ...     ...      ...
# 15468                          100.00     NaN      NaN     NaN      NaN
# 15469                          100.00     NaN      NaN     NaN      NaN
# 15470                          100.00     NaN      NaN     NaN      NaN
# 15471                          100.00     NaN      NaN     NaN      NaN
# 15472                          100.00     NaN      NaN     NaN      NaN
#
#        accessibility_mean_x GID_0_y NAME_0_y   GID_1_y    NAME_1_y  \
# 0                       NaN     ESP    Spain  ESP.16_1  pais_vasco
# 1                       NaN     ESP    Spain  ESP.16_1  pais_vasco
# 2                       NaN     ESP    Spain  ESP.16_1  pais_vasco
# 3                       NaN     ESP    Spain  ESP.16_1  pais_vasco
# 4                       NaN     ESP    Spain  ESP.16_1  pais_vasco
# ...                     ...     ...      ...       ...         ...
# 15468                   NaN     NaN      NaN       NaN         NaN
# 15469                   NaN     NaN      NaN       NaN         NaN
# 15470                   NaN     NaN      NaN       NaN         NaN
# 15471                   NaN     NaN      NaN       NaN         NaN
# 15472                   NaN     NaN      NaN       NaN         NaN
#
#        accessibility_mean_y
# 0                 18.406372
# 1                 18.406372
# 2                 18.406372
# 3                 18.406372
# 4                 18.406372
# ...                     ...
# 15468                   NaN
# 15469                   NaN
# 15470                   NaN
# 15471                   NaN
# 15472                   NaN
#
# [15473 rows x 31 columns]

# %%
union.drop(['GID_0_x','NAME_0_x','GID_1_x','NAME_1_x','accessibility_mean_x','GID_0_y','NAME_0_y','GID_1_y'],axis=1,inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa cities_es/province_es cities_es/province  \
# 0    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 1    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 2    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 3    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 4    araba  pais_vasco  pais_vasco               amurrio            amurrio
#
#   cities_es/ccaa_es    cities_es/ccaa cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 1  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 2           amurrio           amurrio            amurrio               alava
# 3           amurrio           amurrio            amurrio               alava
# 4           amurrio           amurrio            amurrio               alava
#
#   province_es/ccaa province/ccaa_es province/ccaa  \
# 0            alava            araba         araba
# 1            alava            araba         araba
# 2            alava            araba         araba
# 3            alava            araba         araba
# 4            alava            araba         araba
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942
#
#    bus_based_companies_count  Calidad_Cobertura_fija&movil_%    NAME_1_y  \
# 0                        NaN                           65.00  pais_vasco
# 1                        NaN                           65.00  pais_vasco
# 2                        NaN                           62.75  pais_vasco
# 3                        NaN                           62.75  pais_vasco
# 4                        NaN                           62.75  pais_vasco
#
#    accessibility_mean_y
# 0             18.406372
# 1             18.406372
# 2             18.406372
# 3             18.406372
# 4             18.406372

# %%
union[union['accessibility_mean_y']>0]
# Out:
#        ine_code postal_code              cities_es                 cities  \
# 0          1001       01240       alegria_dulantzi       alegria_dulantzi
# 1          1001       01193       alegria_dulantzi       alegria_dulantzi
# 2          1002       01450                amurrio                amurrio
# 3          1002       01468                amurrio                amurrio
# 4          1002       01470                amurrio                amurrio
# ...         ...         ...                    ...                    ...
# 15446     50298       50830                 alagon                 alagon
# 15447     50298       50810                  zuera                  zuera
# 15448     50901       50619                   asin                   asin
# 15449     50902       50616           piedratajada           piedratajada
# 15450     50903       50162  villamayor_de_gallego  villamayor_de_gallego
#
#       province_es  province     ccaa_es        ccaa  cities_es/province_es  \
# 0           alava     araba  pais_vasco  pais_vasco       alegria_dulantzi
# 1           alava     araba  pais_vasco  pais_vasco       alegria_dulantzi
# 2           alava     araba  pais_vasco  pais_vasco                amurrio
# 3           alava     araba  pais_vasco  pais_vasco                amurrio
# 4           alava     araba  pais_vasco  pais_vasco                amurrio
# ...           ...       ...         ...         ...                    ...
# 15446    zaragoza  zaragoza      aragon      aragon                 alagon
# 15447    zaragoza  zaragoza      aragon      aragon                  zuera
# 15448    zaragoza  zaragoza      aragon      aragon                   asin
# 15449    zaragoza  zaragoza      aragon      aragon           piedratajada
# 15450    zaragoza  zaragoza      aragon      aragon  villamayor_de_gallego
#
#           cities_es/province      cities_es/ccaa_es         cities_es/ccaa  \
# 0           alegria_dulantzi       alegria_dulantzi       alegria_dulantzi
# 1           alegria_dulantzi       alegria_dulantzi       alegria_dulantzi
# 2                    amurrio                amurrio                amurrio
# 3                    amurrio                amurrio                amurrio
# 4                    amurrio                amurrio                amurrio
# ...                      ...                    ...                    ...
# 15446                 alagon                 alagon                 alagon
# 15447                  zuera                  zuera                  zuera
# 15448                   asin                   asin                   asin
# 15449           piedratajada           piedratajada           piedratajada
# 15450  villamayor_de_gallego  villamayor_de_gallego  villamayor_de_gallego
#
#           cities/province_es province_es/ccaa_es province_es/ccaa  \
# 0           alegria_dulantzi               alava            alava
# 1           alegria_dulantzi               alava            alava
# 2                    amurrio               alava            alava
# 3                    amurrio               alava            alava
# 4                    amurrio               alava            alava
# ...                      ...                 ...              ...
# 15446                 alagon            zaragoza         zaragoza
# 15447                  zuera            zaragoza         zaragoza
# 15448                   asin            zaragoza         zaragoza
# 15449           piedratajada            zaragoza         zaragoza
# 15450  villamayor_de_gallego            zaragoza         zaragoza
#
#       province/ccaa_es province/ccaa  Total: Millones vehículos-km  \
# 0                araba         araba                       1869.30
# 1                araba         araba                       1869.30
# 2                araba         araba                       1869.30
# 3                araba         araba                       1869.30
# 4                araba         araba                       1869.30
# ...                ...           ...                           ...
# 15446         zaragoza      zaragoza                       4539.27
# 15447         zaragoza      zaragoza                       4539.27
# 15448         zaragoza      zaragoza                       4539.27
# 15449         zaragoza      zaragoza                       4539.27
# 15450         zaragoza      zaragoza                       4539.27
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 15446                             0.983211                        NaN
# 15447                             0.983211                        NaN
# 15448                             0.983211                        NaN
# 15449                             0.983211                        NaN
# 15450                             0.983211                        NaN
#
#        Calidad_Cobertura_fija&movil_%    NAME_1_y  accessibility_mean_y
# 0                               65.00  pais_vasco             18.406372
# 1                               65.00  pais_vasco             18.406372
# 2                               62.75  pais_vasco             18.406372
# 3                               62.75  pais_vasco             18.406372
# 4                               62.75  pais_vasco             18.406372
# ...                               ...         ...                   ...
# 15446                          100.00      aragon             62.648308
# 15447                           88.75      aragon             62.648308
# 15448                           52.50      aragon             62.648308
# 15449                           22.50      aragon             62.648308
# 15450                           77.50      aragon             62.648308
#
# [14593 rows x 23 columns]

# %%
union.drop('NAME_1_y', axis=1,inplace=True)
union.head()
# Out:
#    ine_code postal_code         cities_es            cities province_es  \
# 0      1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1      1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2      1002       01450           amurrio           amurrio       alava
# 3      1002       01468           amurrio           amurrio       alava
# 4      1002       01470           amurrio           amurrio       alava
#
#   province     ccaa_es        ccaa cities_es/province_es cities_es/province  \
# 0    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 1    araba  pais_vasco  pais_vasco      alegria_dulantzi   alegria_dulantzi
# 2    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 3    araba  pais_vasco  pais_vasco               amurrio            amurrio
# 4    araba  pais_vasco  pais_vasco               amurrio            amurrio
#
#   cities_es/ccaa_es    cities_es/ccaa cities/province_es province_es/ccaa_es  \
# 0  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 1  alegria_dulantzi  alegria_dulantzi   alegria_dulantzi               alava
# 2           amurrio           amurrio            amurrio               alava
# 3           amurrio           amurrio            amurrio               alava
# 4           amurrio           amurrio            amurrio               alava
#
#   province_es/ccaa province/ccaa_es province/ccaa  \
# 0            alava            araba         araba
# 1            alava            araba         araba
# 2            alava            araba         araba
# 3            alava            araba         araba
# 4            alava            araba         araba
#
#    Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 0                        1869.3                             0.832942
# 1                        1869.3                             0.832942
# 2                        1869.3                             0.832942
# 3                        1869.3                             0.832942
# 4                        1869.3                             0.832942
#
#    bus_based_companies_count  Calidad_Cobertura_fija&movil_%  \
# 0                        NaN                           65.00
# 1                        NaN                           65.00
# 2                        NaN                           62.75
# 3                        NaN                           62.75
# 4                        NaN                           62.75
#
#    accessibility_mean_y
# 0             18.406372
# 1             18.406372
# 2             18.406372
# 3             18.406372
# 4             18.406372

# %%
estaciones = pd.read_csv('recursos_estaciones_renfe_clean.csv',index_col=None,dtype={'C.P.': object})
estaciones
# Out:
#       CÓDIGO   C.P.  POBLACION  PROVINCIA CERCANIAS FEVE AVE  \
# 0      31412  15008   coruna_a   coruna_a        NO   NO  SI
# 1       5129  15569    cerdido   coruna_a        NO   SI  NO
# 2      31303  32570     maside    ourense        NO   NO  NO
# 3      31205  32540   gudina_a    ourense        NO   NO  NO
# 4      20213  32350      rua_a    ourense        NO   NO  NO
# ...      ...    ...        ...        ...       ...  ...  ..
# 1493   13304  48013     bilbao    bizkaia        SI   NO  NO
# 1494    5457  48013     bilbao    bizkaia        NO   SI  NO
# 1495   78100  50800      zuera   zaragoza        NO   NO  NO
# 1496   11400  20700  zumarraga   gipuzkoa        SI   NO  NO
# 1497   14215  39479   pielagos  cantabria        SI   NO  NO
#
#       numero_estaciones
# 0                     2
# 1                     2
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 1493                 14
# 1494                 14
# 1495                  1
# 1496                  1
# 1497                  5
#
# [1498 rows x 8 columns]

# %%
union = pd.merge(union, estaciones, left_on='postal_code',right_on='C.P.', how='left')
union
# Out:
#        ine_code postal_code         cities_es            cities province_es  \
# 0          1001       01240  alegria_dulantzi  alegria_dulantzi       alava
# 1          1001       01193  alegria_dulantzi  alegria_dulantzi       alava
# 2          1002       01450           amurrio           amurrio       alava
# 3          1002       01468           amurrio           amurrio       alava
# 4          1002       01470           amurrio           amurrio       alava
# ...         ...         ...               ...               ...         ...
# 17317     52001       52004           melilla           melilla     melilla
# 17318     52001       52005           melilla           melilla     melilla
# 17319     52001       52005           melilla           melilla     melilla
# 17320     52001       52006           melilla           melilla     melilla
# 17321     52001       52006           melilla           melilla     melilla
#
#       province     ccaa_es        ccaa cities_es/province_es  \
# 0        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 1        araba  pais_vasco  pais_vasco      alegria_dulantzi
# 2        araba  pais_vasco  pais_vasco               amurrio
# 3        araba  pais_vasco  pais_vasco               amurrio
# 4        araba  pais_vasco  pais_vasco               amurrio
# ...        ...         ...         ...                   ...
# 17317  melilla     melilla     melilla               melilla
# 17318  melilla     melilla     melilla               melilla
# 17319  melilla     melilla     melilla               melilla
# 17320  melilla     melilla     melilla               melilla
# 17321  melilla     melilla     melilla               melilla
#
#       cities_es/province cities_es/ccaa_es    cities_es/ccaa  \
# 0       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 1       alegria_dulantzi  alegria_dulantzi  alegria_dulantzi
# 2                amurrio           amurrio           amurrio
# 3                amurrio           amurrio           amurrio
# 4                amurrio           amurrio           amurrio
# ...                  ...               ...               ...
# 17317            melilla           melilla           melilla
# 17318            melilla           melilla           melilla
# 17319            melilla           melilla           melilla
# 17320            melilla           melilla           melilla
# 17321            melilla           melilla           melilla
#
#       cities/province_es province_es/ccaa_es province_es/ccaa  \
# 0       alegria_dulantzi               alava            alava
# 1       alegria_dulantzi               alava            alava
# 2                amurrio               alava            alava
# 3                amurrio               alava            alava
# 4                amurrio               alava            alava
# ...                  ...                 ...              ...
# 17317            melilla             melilla          melilla
# 17318            melilla             melilla          melilla
# 17319            melilla             melilla          melilla
# 17320            melilla             melilla          melilla
# 17321            melilla             melilla          melilla
#
#       province/ccaa_es province/ccaa  Total: Millones vehículos-km  \
# 0                araba         araba                        1869.3
# 1                araba         araba                        1869.3
# 2                araba         araba                        1869.3
# 3                araba         araba                        1869.3
# 4                araba         araba                        1869.3
# ...                ...           ...                           ...
# 17317          melilla       melilla                           0.0
# 17318          melilla       melilla                           0.0
# 17319          melilla       melilla                           0.0
# 17320          melilla       melilla                           0.0
# 17321          melilla       melilla                           0.0
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 0                                 0.832942                        NaN
# 1                                 0.832942                        NaN
# 2                                 0.832942                        NaN
# 3                                 0.832942                        NaN
# 4                                 0.832942                        NaN
# ...                                    ...                        ...
# 17317                                  NaN                        NaN
# 17318                                  NaN                        NaN
# 17319                                  NaN                        NaN
# 17320                                  NaN                        NaN
# 17321                                  NaN                        NaN
#
#        Calidad_Cobertura_fija&movil_%  accessibility_mean_y C.P._x  \
# 0                               65.00             18.406372    NaN
# 1                               65.00             18.406372    NaN
# 2                               62.75             18.406372    NaN
# 3                               62.75             18.406372    NaN
# 4                               62.75             18.406372    NaN
# ...                               ...                   ...    ...
# 17317                          100.00                   NaN    NaN
# 17318                          100.00                   NaN    NaN
# 17319                          100.00                   NaN    NaN
# 17320                          100.00                   NaN    NaN
# 17321                          100.00                   NaN    NaN
#
#       POBLACION_x PROVINCIA_x CERCANIAS_x FEVE_x AVE_x  numero_estaciones_x  \
# 0             NaN         NaN         NaN    NaN   NaN                  NaN
# 1             NaN         NaN         NaN    NaN   NaN                  NaN
# 2             NaN         NaN         NaN    NaN   NaN                  NaN
# 3             NaN         NaN         NaN    NaN   NaN                  NaN
# 4             NaN         NaN         NaN    NaN   NaN                  NaN
# ...           ...         ...         ...    ...   ...                  ...
# 17317         NaN         NaN         NaN    NaN   NaN                  NaN
# 17318         NaN         NaN         NaN    NaN   NaN                  NaN
# 17319         NaN         NaN         NaN    NaN   NaN                  NaN
# 17320         NaN         NaN         NaN    NaN   NaN                  NaN
# 17321         NaN         NaN         NaN    NaN   NaN                  NaN
#
#        CÓDIGO C.P._y POBLACION_y PROVINCIA_y CERCANIAS_y FEVE_y AVE_y  \
# 0         NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 1         NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 2         NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 3         NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 4         NaN    NaN         NaN         NaN         NaN    NaN   NaN
# ...       ...    ...         ...         ...         ...    ...   ...
# 17317     NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 17318     NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 17319     NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 17320     NaN    NaN         NaN         NaN         NaN    NaN   NaN
# 17321     NaN    NaN         NaN         NaN         NaN    NaN   NaN
#
#        numero_estaciones_y
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 17317                  NaN
# 17318                  NaN
# 17319                  NaN
# 17320                  NaN
# 17321                  NaN
#
# [17322 rows x 37 columns]

# %%
union[union['numero_estaciones_y']>0]
# Out:
#        ine_code postal_code              cities_es                 cities  \
# 2483       9306       34492  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2484       9306       34492  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2546       9373       34492  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2547       9373       34492  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2740      10037       10005                caceres                caceres
# ...         ...         ...                    ...                    ...
# 17282     50297       50006               zaragoza               zaragoza
# 17286     50297       50011               zaragoza               zaragoza
# 17288     50297       50013               zaragoza               zaragoza
# 17294     50298       50800                  zuera                  zuera
# 17295     50298       50830                 alagon                 alagon
#
#       province_es  province          ccaa_es             ccaa  \
# 2483       burgos    burgos  castilla_y_leon  castilla_y_leon
# 2484     palencia  palencia  castilla_y_leon  castilla_y_leon
# 2546       burgos    burgos  castilla_y_leon  castilla_y_leon
# 2547     palencia  palencia  castilla_y_leon  castilla_y_leon
# 2740      caceres   caceres      extremadura      extremadura
# ...           ...       ...              ...              ...
# 17282    zaragoza  zaragoza           aragon           aragon
# 17286    zaragoza  zaragoza           aragon           aragon
# 17288    zaragoza  zaragoza           aragon           aragon
# 17294    zaragoza  zaragoza           aragon           aragon
# 17295    zaragoza  zaragoza           aragon           aragon
#
#        cities_es/province_es     cities_es/province      cities_es/ccaa_es  \
# 2483   rebolledo_de_la_torre  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2484   rebolledo_de_la_torre  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2546   rebolledo_de_la_torre  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2547   rebolledo_de_la_torre  rebolledo_de_la_torre  rebolledo_de_la_torre
# 2740                 caceres                caceres                caceres
# ...                      ...                    ...                    ...
# 17282               zaragoza               zaragoza               zaragoza
# 17286               zaragoza               zaragoza               zaragoza
# 17288               zaragoza               zaragoza               zaragoza
# 17294                  zuera                  zuera                  zuera
# 17295                 alagon                 alagon                 alagon
#
#               cities_es/ccaa     cities/province_es province_es/ccaa_es  \
# 2483   rebolledo_de_la_torre  rebolledo_de_la_torre              burgos
# 2484   rebolledo_de_la_torre  rebolledo_de_la_torre            palencia
# 2546   rebolledo_de_la_torre  rebolledo_de_la_torre              burgos
# 2547   rebolledo_de_la_torre  rebolledo_de_la_torre            palencia
# 2740                 caceres                caceres             caceres
# ...                      ...                    ...                 ...
# 17282               zaragoza               zaragoza            zaragoza
# 17286               zaragoza               zaragoza            zaragoza
# 17288               zaragoza               zaragoza            zaragoza
# 17294                  zuera                  zuera            zaragoza
# 17295                 alagon                 alagon            zaragoza
#
#       province_es/ccaa province/ccaa_es province/ccaa  \
# 2483            burgos           burgos        burgos
# 2484          palencia         palencia      palencia
# 2546            burgos           burgos        burgos
# 2547          palencia         palencia      palencia
# 2740           caceres          caceres       caceres
# ...                ...              ...           ...
# 17282         zaragoza         zaragoza      zaragoza
# 17286         zaragoza         zaragoza      zaragoza
# 17288         zaragoza         zaragoza      zaragoza
# 17294         zaragoza         zaragoza      zaragoza
# 17295         zaragoza         zaragoza      zaragoza
#
#        Total: Millones vehículos-km  porcentaje_carreteras_ccaa_y_estado  \
# 2483                        3736.07                             0.914741
# 2484                        1612.95                             0.874280
# 2546                        3736.07                             0.914741
# 2547                        1612.95                             0.874280
# 2740                        3025.91                             0.830848
# ...                             ...                                  ...
# 17282                       4539.27                             0.983211
# 17286                       4539.27                             0.983211
# 17288                       4539.27                             0.983211
# 17294                       4539.27                             0.983211
# 17295                       4539.27                             0.983211
#
#        bus_based_companies_count  Calidad_Cobertura_fija&movil_%  \
# 2483                         NaN                           30.42
# 2484                         NaN                           30.42
# 2546                         NaN                           30.42
# 2547                         NaN                           30.42
# 2740                         3.0                           71.88
# ...                          ...                             ...
# 17282                        1.0                           96.00
# 17286                        1.0                           96.00
# 17288                        1.0                           96.00
# 17294                        NaN                           88.75
# 17295                        NaN                          100.00
#
#        accessibility_mean_y C.P._x            POBLACION_x PROVINCIA_x  \
# 2483              52.068456  34492      aguilar_de_campoo    palencia
# 2484              52.068456  34492      aguilar_de_campoo    palencia
# 2546              52.068456  34492      aguilar_de_campoo    palencia
# 2547              52.068456  34492      aguilar_de_campoo    palencia
# 2740              63.744231  10005                caceres     caceres
# ...                     ...    ...                    ...         ...
# 17282             62.648308  50006               zaragoza    zaragoza
# 17286             62.648308  50011               zaragoza    zaragoza
# 17288             62.648308  50013               zaragoza    zaragoza
# 17294             62.648308  50800                  zuera    zaragoza
# 17295             62.648308  50830  villanueva_de_gallego    zaragoza
#
#       CERCANIAS_x FEVE_x AVE_x  numero_estaciones_x   CÓDIGO C.P._y  \
# 2483           NO     NO    NO                  2.0  14113.0  34492
# 2484           NO     NO    NO                  2.0  14113.0  34492
# 2546           NO     NO    NO                  2.0  14113.0  34492
# 2547           NO     NO    NO                  2.0  14113.0  34492
# 2740           NO     NO    NO                  2.0  35400.0  10005
# ...           ...    ...   ...                  ...      ...    ...
# 17282          SI     NO    NO                  5.0  70807.0  50006
# 17286          SI     NO    SI                  5.0   4040.0  50011
# 17288          SI     NO    NO                  5.0  71100.0  50013
# 17294          NO     NO    NO                  1.0  78100.0  50800
# 17295          NO     NO    NO                  1.0  78005.0  50830
#
#                  POBLACION_y PROVINCIA_y CERCANIAS_y FEVE_y AVE_y  \
# 2483       aguilar_de_campoo    palencia          NO     NO    NO
# 2484       aguilar_de_campoo    palencia          NO     NO    NO
# 2546       aguilar_de_campoo    palencia          NO     NO    NO
# 2547       aguilar_de_campoo    palencia          NO     NO    NO
# 2740                 caceres     caceres          NO     NO    NO
# ...                      ...         ...         ...    ...   ...
# 17282               zaragoza    zaragoza          SI     NO    NO
# 17286               zaragoza    zaragoza          SI     NO    SI
# 17288               zaragoza    zaragoza          SI     NO    NO
# 17294                  zuera    zaragoza          NO     NO    NO
# 17295  villanueva_de_gallego    zaragoza          NO     NO    NO
#
#        numero_estaciones_y
# 2483                   2.0
# 2484                   2.0
# 2546                   2.0
# 2547                   2.0
# 2740                   2.0
# ...                    ...
# 17282                  5.0
# 17286                  5.0
# 17288                  5.0
# 17294                  1.0
# 17295                  1.0
#
# [2773 rows x 37 columns]

# %%
estaciones.shape
# Out:
# (1498, 8)

# %%
union[union['numero_estaciones']>0]
# Out:
#        ine_code postal_code cities_es    cities province_es  province ccaa_es  \
# 134        2003         NaN       NaN       NaN         NaN       NaN     NaN
# 135        2003         NaN       NaN       NaN         NaN       NaN     NaN
# 152        2006         NaN       NaN       NaN         NaN       NaN     NaN
# 153        2006         NaN       NaN       NaN         NaN       NaN     NaN
# 159        2008         NaN       NaN       NaN         NaN       NaN     NaN
# ...         ...         ...       ...       ...         ...       ...     ...
# 16222     50297       50006  zaragoza  zaragoza    zaragoza  zaragoza  aragon
# 16226     50297       50011  zaragoza  zaragoza    zaragoza  zaragoza  aragon
# 16228     50297       50013  zaragoza  zaragoza    zaragoza  zaragoza  aragon
# 16234     50298       50800     zuera     zuera    zaragoza  zaragoza  aragon
# 16235     50298       50830    alagon    alagon    zaragoza  zaragoza  aragon
#
#          ccaa cities_es/province_es cities_es/province cities_es/ccaa_es  \
# 134       NaN                   NaN                NaN               NaN
# 135       NaN                   NaN                NaN               NaN
# 152       NaN                   NaN                NaN               NaN
# 153       NaN                   NaN                NaN               NaN
# 159       NaN                   NaN                NaN               NaN
# ...       ...                   ...                ...               ...
# 16222  aragon              zaragoza           zaragoza          zaragoza
# 16226  aragon              zaragoza           zaragoza          zaragoza
# 16228  aragon              zaragoza           zaragoza          zaragoza
# 16234  aragon                 zuera              zuera             zuera
# 16235  aragon                alagon             alagon            alagon
#
#       cities_es/ccaa cities/province_es province_es/ccaa_es province_es/ccaa  \
# 134              NaN                NaN                 NaN              NaN
# 135              NaN                NaN                 NaN              NaN
# 152              NaN                NaN                 NaN              NaN
# 153              NaN                NaN                 NaN              NaN
# 159              NaN                NaN                 NaN              NaN
# ...              ...                ...                 ...              ...
# 16222       zaragoza           zaragoza            zaragoza         zaragoza
# 16226       zaragoza           zaragoza            zaragoza         zaragoza
# 16228       zaragoza           zaragoza            zaragoza         zaragoza
# 16234          zuera              zuera            zaragoza         zaragoza
# 16235         alagon             alagon            zaragoza         zaragoza
#
#       province/ccaa_es province/ccaa  Total: Millones vehículos-km  \
# 134                NaN           NaN                           NaN
# 135                NaN           NaN                           NaN
# 152                NaN           NaN                           NaN
# 153                NaN           NaN                           NaN
# 159                NaN           NaN                           NaN
# ...                ...           ...                           ...
# 16222         zaragoza      zaragoza                       4539.27
# 16226         zaragoza      zaragoza                       4539.27
# 16228         zaragoza      zaragoza                       4539.27
# 16234         zaragoza      zaragoza                       4539.27
# 16235         zaragoza      zaragoza                       4539.27
#
#        porcentaje_carreteras_ccaa_y_estado  bus_based_companies_count  \
# 134                                    NaN                        NaN
# 135                                    NaN                        NaN
# 152                                    NaN                        NaN
# 153                                    NaN                        NaN
# 159                                    NaN                        NaN
# ...                                    ...                        ...
# 16222                             0.983211                        1.0
# 16226                             0.983211                        1.0
# 16228                             0.983211                        1.0
# 16234                             0.983211                        NaN
# 16235                             0.983211                        NaN
#
#        Calidad_Cobertura_fija&movil_%  accessibility_mean_y   C.P.  \
# 134                               NaN                   NaN    NaN
# 135                               NaN                   NaN    NaN
# 152                               NaN                   NaN    NaN
# 153                               NaN                   NaN    NaN
# 159                               NaN                   NaN    NaN
# ...                               ...                   ...    ...
# 16222                           96.00             62.648308  50006
# 16226                           96.00             62.648308  50011
# 16228                           96.00             62.648308  50013
# 16234                           88.75             62.648308  50800
# 16235                          100.00             62.648308  50830
#
#                    POBLACION PROVINCIA CERCANIAS FEVE AVE  numero_estaciones
# 134                   oviedo  asturias        NO   SI  NO               15.0
# 135                  candamo  asturias        NO   SI  NO                3.0
# 152                   oviedo  asturias        NO   SI  NO               15.0
# 153                  candamo  asturias        NO   SI  NO                3.0
# 159                   oviedo  asturias        NO   SI  NO               15.0
# ...                      ...       ...       ...  ...  ..                ...
# 16222               zaragoza  zaragoza        SI   NO  NO                5.0
# 16226               zaragoza  zaragoza        SI   NO  SI                5.0
# 16228               zaragoza  zaragoza        SI   NO  NO                5.0
# 16234                  zuera  zaragoza        NO   NO  NO                1.0
# 16235  villanueva_de_gallego  zaragoza        NO   NO  NO                1.0
#
# [2594 rows x 29 columns]
