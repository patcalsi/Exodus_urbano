# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import datasets
from io import StringIO
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import metrics
# %matplotlib inline

# %%
Comercios = pd.read_excel('Comercios_municipios.xls')

# %%
Comercios
# Out:
#                                                  Total B_E Industria  \
# 0                                                 2019          2019
# 1                              Total Nacional  3363197        199076
# 2                              01 Araba/Álava    18678          1942
# 3                      01001 Alegría-Dulantzi      148            20
# 4                               01002 Amurrio      600            63
# ...                                       ...      ...           ...
# 8187              50903 Villamayor de Gállego      166            17
# 8188                                 51 Ceuta     3789            82
# 8189                              51001 Ceuta     3789            82
# 8190                               52 Melilla     5304           117
# 8191                            52001 Melilla     5304           117
#
#      F Construcción Comercio, transporte y hostelería  \
# 0              2019                              2019
# ...

# %%
#borro la primera línea que es el año de los datos y no es informativa

Comercios = Comercios.drop([0])

# %%
#Como quiero poner nombre a la primera columna, primero veo como la tiene nombrada el df:
Comercios.columns
# Out:
# Index([' ', 'Total', 'B_E Industria', 'F Construcción',
#        'Comercio, transporte y hostelería', 'J Información y comunicaciones',
#        'K Actividades financieras y de seguros', 'L Actividades inmobiliarias',
#        'Actividades profesionales y técnicas',
#        'Educación, sanidad y servicios sociales', 'Otros servicios personales',
#        'Total servicios'],
#       dtype='object')

# %%
# Ahora, puedo utilizar un replace o renombrar todas las columnas (copia y pego con el nombre que queramos en la columna que queramos)

# Opción de replace:
Comercios.rename(columns={' ':'Region'}, inplace=True)

#Opción copia pega:
# Comercios.columns = ['Region', 'Total', 'B_E Industria', 'F Construcción',
#       'Comercio, transporte y hostelería', 'J Información y comunicaciones',
#       'K Actividades financieras y de seguros', 'L Actividades inmobiliarias',
#       'Actividades profesionales y técnicas',
#       'Educación, sanidad y servicios sociales', 'Otros servicios personales',
#       'Total servicios']

# %%
Comercios
# Out:
#                                        Region    Total B_E Industria  \
# 1                              Total Nacional  3363197        199076
# 2                              01 Araba/Álava    18678          1942
# 3                      01001 Alegría-Dulantzi      148            20
# 4                               01002 Amurrio      600            63
# 5                               01003 Aramaio       50             8
# ...                                       ...      ...           ...
# 8187              50903 Villamayor de Gállego      166            17
# 8188                                 51 Ceuta     3789            82
# 8189                              51001 Ceuta     3789            82
# 8190                               52 Melilla     5304           117
# 8191                            52001 Melilla     5304           117
#
#      F Construcción Comercio, transporte y hostelería  \
# 1            422350                           1215680
# ...

# %%
Comercios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8191 entries, 1 to 8191
# Data columns (total 12 columns):
# Region                                     8191 non-null object
# Total                                      8191 non-null object
# B_E Industria                              8191 non-null object
# F Construcción                             8191 non-null object
# Comercio, transporte y hostelería          8191 non-null object
# J Información y comunicaciones             8191 non-null object
# K Actividades financieras y de seguros     8191 non-null object
# L Actividades inmobiliarias                8191 non-null object
# Actividades profesionales y técnicas       8191 non-null object
# Educación, sanidad y servicios sociales    8191 non-null object
# Otros servicios personales                 8191 non-null object
# Total servicios                            8191 non-null object
# dtypes: object(12)
# memory usage: 831.9+ KB

# %%
# Guardamos en formato csv:
Comercios.to_csv('Economia_Comercios_2019.csv', header=False, index=False)
